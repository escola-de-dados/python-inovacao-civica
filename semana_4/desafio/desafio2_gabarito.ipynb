# %% [markdown]
# # Desafio 2
#
# Escolha a página do wikipédia relacionada a lista de parlamentares do seu estado e extraia as tabelas existentes na página.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

url = (
  "https://pt.wikipedia.org/wiki/Lista_de_parlamentares_de_Pernambuco"
)

tables = pd.read_html(url)

# %% [markdown]
# ## Quantas tabelas existem na página?

# %%
len(tables)
# Out:
# 4

# %%
for id, table in enumerate(tables):
    print(f"Tabela {id}")
    print(table.info())
    print("\n")
# Out:
# Tabela 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Senadores eleitos  25 non-null     object
#  1   Naturalidade       25 non-null     object
#  2   Mandatos           25 non-null     object
#  3   Ano da eleição     25 non-null     object
#  4   Notas              10 non-null     object
# dtypes: object(5)
# memory usage: 1.1+ KB
# None
#
#
# Tabela 1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Deputados federais eleitos  187 non-null    object
#  1   Naturalidade                187 non-null    object
#  2   Mandatos                    187 non-null    object
#  3   Ano da eleição              187 non-null    object
#  4   Notas                       33 non-null     object
# dtypes: object(5)
# memory usage: 7.4+ KB
# None
#
#
# Tabela 2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   vde Eleições estaduais em Pernambuco    2 non-null      object
#  1   vde Eleições estaduais em Pernambuco.1  2 non-null      object
#  2   vde Eleições estaduais em Pernambuco.2  1 non-null      object
# dtypes: object(3)
# memory usage: 176.0+ bytes
# None
#
#
# Tabela 3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   vdeParlamentares do Congresso Nacional do Brasil por estado    1 non-null      object
#  1   vdeParlamentares do Congresso Nacional do Brasil por estado.1  1 non-null      object
# dtypes: object(2)
# memory usage: 144.0+ bytes
# None

# %% [markdown]
# ## Qual o total de senadores já eleitos no seu estado?

# %%
tb_senadores = tables[0]
tb_senadores
# Out:
#           Senadores eleitos                 Naturalidade      Mandatos  \
# 0              Marco Maciel                   Recife, PE            03
# 1              Novais Filho  Cabo de Santo Agostinho, PE            02
# 2            Apolônio Sales                  Altinho, PE            02
# 3        Jarbas Vasconcelos                 Vicência, PE            02
# 4            Humberto Costa                 Campinas, SP            02
# 5             Etelvino Lins                 Sertânia, PE            01
# 6           Jarbas Maranhão           Nazaré da Mata, PE            01
# 7           Barros Carvalho                 Palmares, PE            01
# 8    José Ermírio de Moraes           Nazaré da Mata, PE            01
# 9         Pessoa de Queiroz                Umbuzeiro, PB            01
# 10             João Cleofas   Vitória de Santo Antão, PE            01
# 11             Paulo Guerra           Nazaré da Mata, PE            01
# 12            Wilson Campos   Brejo da Madre de Deus, PE            01
# 13            Marcos Freire                   Recife, PE            01
# 14           Aderbal Jurema              João Pessoa, PB            01
# 15              Nilo Coelho                Petrolina, PE            01
# 16           Antônio Farias                  Surubim, PE            01
# 17        Mansueto de Lavor                 Barbalha, CE            01
# 18            Carlos Wilson                   Recife, PE            01
# 19           Roberto Freire                   Recife, PE            01
# 20               José Jorge                   Recife, PE            01
# 21            Sérgio Guerra                   Recife, PE            01
# 22         Armando Monteiro                   Recife, PE            01
# 23  Fernando Bezerra Coelho                Petrolina, PE            01
# 24             Fonte:[1][3]                 Fonte:[1][3]  Fonte:[1][3]
#
#       Ano da eleição             Notas
# 0   1982, 1990, 2002          [nota 1]
# 1         1945, 1954               NaN
# 2         1947, 1950               NaN
# 3         2006, 2018               NaN
# 4         2010, 2018               NaN
# 5               1945          [nota 2]
# 6               1954               NaN
# 7               1958               NaN
# 8               1962               NaN
# 9               1962               NaN
# 10              1966               NaN
# 11              1970          [nota 3]
# 12              1970          [nota 4]
# 13              1974               NaN
# 14              1978  [nota 5][nota 6]
# 15              1978          [nota 7]
# 16              1986          [nota 8]
# 17              1986               NaN
# 18              1994          [nota 9]
# 19              1994         [nota 10]
# 20              1998               NaN
# 21              2002               NaN
# 22              2010               NaN
# 23              2014               NaN
# 24      Fonte:[1][3]      Fonte:[1][3]

# %%
tb_senadores = tb_senadores.iloc[:-1] # para remover a última linha
tb_senadores
# Out:
#           Senadores eleitos                 Naturalidade Mandatos  \
# 0              Marco Maciel                   Recife, PE       03
# 1              Novais Filho  Cabo de Santo Agostinho, PE       02
# 2            Apolônio Sales                  Altinho, PE       02
# 3        Jarbas Vasconcelos                 Vicência, PE       02
# 4            Humberto Costa                 Campinas, SP       02
# 5             Etelvino Lins                 Sertânia, PE       01
# 6           Jarbas Maranhão           Nazaré da Mata, PE       01
# 7           Barros Carvalho                 Palmares, PE       01
# 8    José Ermírio de Moraes           Nazaré da Mata, PE       01
# 9         Pessoa de Queiroz                Umbuzeiro, PB       01
# 10             João Cleofas   Vitória de Santo Antão, PE       01
# 11             Paulo Guerra           Nazaré da Mata, PE       01
# 12            Wilson Campos   Brejo da Madre de Deus, PE       01
# 13            Marcos Freire                   Recife, PE       01
# 14           Aderbal Jurema              João Pessoa, PB       01
# 15              Nilo Coelho                Petrolina, PE       01
# 16           Antônio Farias                  Surubim, PE       01
# 17        Mansueto de Lavor                 Barbalha, CE       01
# 18            Carlos Wilson                   Recife, PE       01
# 19           Roberto Freire                   Recife, PE       01
# 20               José Jorge                   Recife, PE       01
# 21            Sérgio Guerra                   Recife, PE       01
# 22         Armando Monteiro                   Recife, PE       01
# 23  Fernando Bezerra Coelho                Petrolina, PE       01
#
#       Ano da eleição             Notas
# 0   1982, 1990, 2002          [nota 1]
# 1         1945, 1954               NaN
# 2         1947, 1950               NaN
# 3         2006, 2018               NaN
# 4         2010, 2018               NaN
# 5               1945          [nota 2]
# 6               1954               NaN
# 7               1958               NaN
# 8               1962               NaN
# 9               1962               NaN
# 10              1966               NaN
# 11              1970          [nota 3]
# 12              1970          [nota 4]
# 13              1974               NaN
# 14              1978  [nota 5][nota 6]
# 15              1978          [nota 7]
# 16              1986          [nota 8]
# 17              1986               NaN
# 18              1994          [nota 9]
# 19              1994         [nota 10]
# 20              1998               NaN
# 21              2002               NaN
# 22              2010               NaN
# 23              2014               NaN

# %%
len(tb_senadores["Senadores eleitos"].unique())
# Out:
# 24

# %%
# também podemos responder assim
tb_senadores.shape[0]
# Out:
# 24

# %% [markdown]
# ## Qual o total de deputados federais já eleitos no seu estado?

# %%
tb_federais = tables[1]
tb_federais
# Out:
#     Deputados federais eleitos        Naturalidade      Mandatos  \
# 0           Inocêncio Oliveira   Serra Talhada, PE            10
# 1               Osvaldo Coelho        Juazeiro, BA            08
# 2                Ricardo Fiuza       Fortaleza, CE            08
# 3             Gonzaga Patriota        Sertânia, PE            08
# 4        José Mendonça Bezerra     Belo Jardim, PE            07
# ..                         ...                 ...           ...
# 182             Marília Arraes          Recife, PE            01
# 183              Ossesio Silva  Rio de Janeiro, RJ            01
# 184         Sílvio Costa Filho          Recife, PE            01
# 185              Túlio Gadêlha          Recife, PE            01
# 186               Fonte:[2][3]        Fonte:[2][3]  Fonte:[2][3]
#
#                                         Ano da eleição         Notas
# 0    1974, 1978, 1982, 1986, 1990, 1994, 1998, 2002...           NaN
# 1       1966, 1978, 1982, 1986, 1990, 1994, 1998, 2002           NaN
# 2       1970, 1974, 1978, 1982, 1986, 1990, 1998, 2002     [nota 11]
# 3       1986, 1994, 1998, 2002, 2006, 2010, 2014, 2018           NaN
# 4             1982, 1986, 1990, 1994, 1998, 2002, 2006           NaN
# ..                                                 ...           ...
# 182                                               2018           NaN
# 183                                               2018           NaN
# 184                                               2018           NaN
# 185                                               2018           NaN
# 186                                       Fonte:[2][3]  Fonte:[2][3]
#
# [187 rows x 5 columns]

# %%
tb_federais = tb_federais.iloc[:-1]
tb_federais
# Out:
#     Deputados federais eleitos        Naturalidade Mandatos  \
# 0           Inocêncio Oliveira   Serra Talhada, PE       10
# 1               Osvaldo Coelho        Juazeiro, BA       08
# 2                Ricardo Fiuza       Fortaleza, CE       08
# 3             Gonzaga Patriota        Sertânia, PE       08
# 4        José Mendonça Bezerra     Belo Jardim, PE       07
# ..                         ...                 ...      ...
# 181                João Campos          Recife, PE       01
# 182             Marília Arraes          Recife, PE       01
# 183              Ossesio Silva  Rio de Janeiro, RJ       01
# 184         Sílvio Costa Filho          Recife, PE       01
# 185              Túlio Gadêlha          Recife, PE       01
#
#                                         Ano da eleição            Notas
# 0    1974, 1978, 1982, 1986, 1990, 1994, 1998, 2002...              NaN
# 1       1966, 1978, 1982, 1986, 1990, 1994, 1998, 2002              NaN
# 2       1970, 1974, 1978, 1982, 1986, 1990, 1998, 2002        [nota 11]
# 3       1986, 1994, 1998, 2002, 2006, 2010, 2014, 2018              NaN
# 4             1982, 1986, 1990, 1994, 1998, 2002, 2006              NaN
# ..                                                 ...              ...
# 181                                               2018  [5][6][nota 37]
# 182                                               2018              NaN
# 183                                               2018              NaN
# 184                                               2018              NaN
# 185                                               2018              NaN
#
# [186 rows x 5 columns]

# %%
tb_federais.shape[0]
# Out:
# 186

# %% [markdown]
# ## Qual o total de deputados e senadores por cidade?
#
# dica: `groupby`

# %%
tb_senadores.groupby("Naturalidade").count()["Senadores eleitos"].sort_values(ascending=False)
# Out:
# Naturalidade
# Recife, PE                     7
# Nazaré da Mata, PE             3
# Petrolina, PE                  2
# Altinho, PE                    1
# Barbalha, CE                   1
# Brejo da Madre de Deus, PE     1
# Cabo de Santo Agostinho, PE    1
# Campinas, SP                   1
# João Pessoa, PB                1
# Palmares, PE                   1
# Sertânia, PE                   1
# Surubim, PE                    1
# Umbuzeiro, PB                  1
# Vicência, PE                   1
# Vitória de Santo Antão, PE     1
# Name: Senadores eleitos, dtype: int64

# %%
tb_federais.groupby("Naturalidade").count()["Deputados federais eleitos"].sort_values(ascending=False)
# Out:
# Naturalidade
# Recife, PE                    80
# Caruaru, PE                    6
# Nazaré da Mata, PE             5
# Vitória de Santo Antão, PE     4
# Limoeiro, PE                   4
#                               ..
# Itambé, PE                     1
# João Alfredo, PE               1
# Amaraji, PE                    1
# Lagoa dos Gatos, PE            1
# Juazeiro do Norte, CE          1
# Name: Deputados federais eleitos, Length: 66, dtype: int64

# %% [markdown]
# ## Qual deputado/senador com mais mandatos?

# %%
max_mandatos_senadores = tb_senadores["Mandatos"].max()
max_mandatos_senadores
# Out:
# '03'

# %%
tb_senadores["Mandatos"] == max_mandatos_senadores
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# Name: Mandatos, dtype: bool

# %%
tb_senadores[tb_senadores["Mandatos"] == max_mandatos_senadores]
# Out:
#   Senadores eleitos Naturalidade Mandatos    Ano da eleição     Notas
# 0      Marco Maciel   Recife, PE       03  1982, 1990, 2002  [nota 1]

# %% [markdown]
# Se cada mandato de senador são 8 anos, então esse senador ficou:

# %%
f"{int(max_mandatos_senadores) * 8} anos como senador"
# Out:
# '24 anos como senador'

# %%
max_mandatos_federais = tb_federais["Mandatos"].max()
max_mandatos_federais
# Out:
# '10'

# %%
tb_federais[tb_federais["Mandatos"] == max_mandatos_federais]
# Out:
#   Deputados federais eleitos       Naturalidade Mandatos  \
# 0         Inocêncio Oliveira  Serra Talhada, PE       10
#
#                                       Ano da eleição Notas
# 0  1974, 1978, 1982, 1986, 1990, 1994, 1998, 2002...   NaN

# %% [markdown]
# Se cada mandato de deputado federal tem duração de 4 anos, então esse deputado ficou:

# %%
f"{int(max_mandatos_federais) * 4} anos como deputado federal"
# Out:
# '40 anos como deputado federal'

# %% [markdown]
# ## Desafio extra
#
# Esse desafio traz uma ideia extra de cruzamento de dados. Fique a vontade para tentar encontrar essas respostas :)
#
# - Se você cruzasse esses dados com os dados da CEAP? Quanto o deputado com maior número de candidaturas gastou?
# - Qual a média dos gastos dos parlamentares do seu estado?

# %%
# No meu caso, como Inocêncio Oliveira teve mandato até 2014,
# eu irei pegar o arquivo de gastos de 2013.
# Você pode alterar, dependendo de até quando foi o mandato do
# deputado com mais candidaturas do seu estado.
url = "http://www.camara.leg.br/cotas/Ano-2013.csv.zip"

DTYPE = {
    'txNomeParlamentar': str,
    'ideCadastro': str,
    'nuCarteiraParlamentar': str,
    'nuLegislatura': str,
    'sgUF': str,
    'sgPartido': str,
    'codLegislatura': str,
    'numSubCota': str,
    'txtDescricao': str,
    'numEspecificacaoSubCota': str,
    'txtDescricaoEspecificacao': str,
    'txtFornecedor': str,
    "cpf": str,
    'txtCNPJCPF': str,
    'txtNumero': str,
    'indTipoDocumento': str,
    'datEmissao': str,
    'vlrDocumento': float,
    'vlrGlosa': str,
    'vlrLiquido': float,
    'numMes': str,
    'numAno': str,
    'numParcela': str,
    'txtPassageiro': str,
    'txtTrecho': str,
    'numLote': str,
    'numRessarcimento': str,
    'nuDeputadoId': str,
    'ideDocumento': str,
}

df_reembolso = pd.read_csv(
    url,
    sep=";",
    dtype=DTYPE,
    compression="zip"
)
df_reembolso.head()
# Out:
#   txNomeParlamentar  cpf ideCadastro nuCarteiraParlamentar nuLegislatura sgUF  \
# 0  LIDERANÇA DO PDT  NaN         NaN                   NaN          2011  NaN
# 1  LIDERANÇA DO PDT  NaN         NaN                   NaN          2011  NaN
# 2  LIDERANÇA DO PDT  NaN         NaN                   NaN          2011  NaN
# 3  LIDERANÇA DO PDT  NaN         NaN                   NaN          2011  NaN
# 4  LIDERANÇA DO PDT  NaN         NaN                   NaN          2011  NaN
#
#   sgPartido codLegislatura numSubCota  \
# 0       NaN             54          1
# 1       NaN             54          1
# 2       NaN             54          1
# 3       NaN             54          1
# 4       NaN             54          1
#
#                                         txtDescricao numEspecificacaoSubCota  \
# 0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...                       0
# 1  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...                       0
# 2  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...                       0
# 3  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...                       0
# 4  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...                       0
#
#   txtDescricaoEspecificacao                      txtFornecedor  \
# 0                       NaN  COMERCIAL DE ALIMENTOS GRANO LTDA
# 1                       NaN  COMERCIAL DE ALIMENTOS GRANO LTDA
# 2                       NaN  COMERCIAL DE ALIMENTOS GRANO LTDA
# 3                       NaN  COMERCIAL DE ALIMENTOS GRANO LTDA
# 4                       NaN  Comercial de Alimentos Grano Ltda
#
#            txtCNPJCPF txtNumero indTipoDocumento           datEmissao  \
# 0  062.784.330/0019-0     52280                0  2013-05-28T00:00:00
# 1  062.784.330/0019-0     53946                0  2013-06-27T00:00:00
# 2  062.784.330/0019-0     56392                0  2013-07-29T00:00:00
# 3  062.784.330/0019-0     58987                0  2013-08-28T00:00:00
# 4  062.784.330/0019-0     61520                0  2013-09-26T00:00:00
#
#    vlrDocumento vlrGlosa  vlrLiquido numMes numAno numParcela txtPassageiro  \
# 0         635.7        0       635.7      6   2013          0           NaN
# 1         545.1        0       545.1      7   2013          0           NaN
# 2         482.3        0       482.3      8   2013          0           NaN
# 3         600.6        0       600.6      9   2013          0           NaN
# 4         544.5        0       544.5      9   2013          0           NaN
#
#   txtTrecho  numLote numRessarcimento  vlrRestituicao nuDeputadoId  \
# 0       NaN  1042075              NaN             NaN         2715
# 1       NaN  1043845              NaN             NaN         2715
# 2       NaN  1050979              NaN             NaN         2715
# 3       NaN  1059955              NaN             NaN         2715
# 4       NaN  1069465              NaN             NaN         2715
#
#   ideDocumento  urlDocumento
# 0      5159141           NaN
# 1      5165750           NaN
# 2      5177451           NaN
# 3      5227489           NaN
# 4      5244951           NaN

# %%
df_reembolso[df_reembolso["sgUF"] == "PE"]["txNomeParlamentar"].unique()
# Out:
# array(['SILVIO COSTA', 'PAULO RUBEM SANTIAGO', 'FERNANDO FERRO',
#        'Gonzaga Patriota', 'INOCÊNCIO OLIVEIRA', 'JOSÉ CHAVES',
#        'MENDONÇA FILHO', 'SERGIO GUERRA', 'Wolney Queiroz',
#        'CARLOS EDUARDO CADOCA', 'PEDRO EUGÊNIO', 'BRUNO ARAÚJO',
#        'Eduardo da Fonte', 'Fernando Coelho Filho', 'Raul Henry',
#        'JOÃO PAULO LIMA', 'ANDERSON FERREIRA', 'JORGE CÔRTE REAL',
#        'LUCIANA SANTOS', 'Pastor Eurico', 'ROBERTO TEIXEIRA',
#        'JOSÉ AUGUSTO MAIA', 'Augusto Coutinho', 'VILALBA',
#        'SEVERINO NINHO'], dtype=object)

# %%
df_reembolso["txNomeParlamentar"].str.upper()
# Out:
# 0         LIDERANÇA DO PDT
# 1         LIDERANÇA DO PDT
# 2         LIDERANÇA DO PDT
# 3         LIDERANÇA DO PDT
# 4         LIDERANÇA DO PDT
#                 ...
# 391523        HELCIO SILVA
# 391524        HELCIO SILVA
# 391525        HELCIO SILVA
# 391526        HELCIO SILVA
# 391527        HELCIO SILVA
# Name: txNomeParlamentar, Length: 391528, dtype: object

# %%
df_reembolso["txNomeParlamentar"] = df_reembolso["txNomeParlamentar"].str.upper()

# %%
tb_federais.loc["Deputados federais eleitos"] = tb_federais["Deputados federais eleitos"].str.upper()

# %%
tb_federais["Deputados federais eleitos"]
# Out:
# 0                                INOCÊNCIO OLIVEIRA
# 1                                    OSVALDO COELHO
# 2                                     RICARDO FIUZA
# 3                                  GONZAGA PATRIOTA
# 4                             JOSÉ MENDONÇA BEZERRA
#                                       ...
# 182                                  MARÍLIA ARRAES
# 183                                   OSSESIO SILVA
# 184                              SÍLVIO COSTA FILHO
# 185                                   TÚLIO GADÊLHA
# Deputados federais eleitos                      NaN
# Name: Deputados federais eleitos, Length: 187, dtype: object

# %%
df_reembolso_pe = df_reembolso[df_reembolso.sgUF == "PE"].merge(
    tb_federais,
    how="inner",
    left_on="txNomeParlamentar",
    right_on="Deputados federais eleitos"
)

df_reembolso_pe.head()
# Out:
#   txNomeParlamentar          cpf ideCadastro nuCarteiraParlamentar  \
# 0      SILVIO COSTA  10481389415        4930                   160
# 1      SILVIO COSTA  10481389415        4930                   160
# 2      SILVIO COSTA  10481389415        4930                   160
# 3      SILVIO COSTA  10481389415        4930                   160
# 4      SILVIO COSTA  10481389415        4930                   160
#
#   nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 0          2011   PE       PSC             54          1
# 1          2011   PE       PSC             54          1
# 2          2011   PE       PSC             54          1
# 3          2011   PE       PSC             54          1
# 4          2011   PE       PSC             54          1
#
#                                         txtDescricao numEspecificacaoSubCota  \
# 0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...                       0
# 1  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...                       0
# 2  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...                       0
# 3  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...                       0
# 4  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...                       0
#
#   txtDescricaoEspecificacao                txtFornecedor         txtCNPJCPF  \
# 0                       NaN  ANTONIO CARLOS BRITO MACIEL  004.933.334/87  -
# 1                       NaN  ANTONIO CARLOS BRITO MACIEL  004.933.334/87  -
# 2                       NaN  ANTONIO CARLOS BRITO MACIEL  004.933.334/87  -
# 3                       NaN  ANTONIO CARLOS BRITO MACIEL  004.933.334/87  -
# 4                       NaN  ANTONIO CARLOS BRITO MACIEL  004.933.334/87  -
#
#   txtNumero indTipoDocumento           datEmissao  vlrDocumento vlrGlosa  \
# 0       002                1  2013-03-05T00:00:00        1700.0        0
# 1       004                1  2013-05-02T00:00:00        1700.0        0
# 2       005                1  2013-06-03T00:00:00        1700.0        0
# 3       006                1  2013-07-01T00:00:00        1700.0        0
# 4       008                1  2013-08-01T00:00:00        1700.0        0
#
#    vlrLiquido numMes numAno numParcela txtPassageiro txtTrecho  numLote  \
# 0      1700.0      2   2013          0           NaN       NaN  1014935
# 1      1700.0      4   2013          0           NaN       NaN  1030692
# 2      1700.0      5   2013          0           NaN       NaN  1036409
# 3      1700.0      6   2013          0           NaN       NaN  1042969
# 4      1700.0      7   2013          0           NaN       NaN  1049530
#
#   numRessarcimento  vlrRestituicao nuDeputadoId ideDocumento  urlDocumento  \
# 0              NaN             NaN         1973      5055221           NaN
# 1              NaN             NaN         1973      5115525           NaN
# 2              NaN             NaN         1973      5136635           NaN
# 3              NaN             NaN         1973      5162066           NaN
# 4              NaN             NaN         1973      5187148           NaN
#
#   Deputados federais eleitos     Naturalidade Mandatos Ano da eleição Notas
# 0               SILVIO COSTA  Rio Formoso, PE       02     2010, 2014   NaN
# 1               SILVIO COSTA  Rio Formoso, PE       02     2010, 2014   NaN
# 2               SILVIO COSTA  Rio Formoso, PE       02     2010, 2014   NaN
# 3               SILVIO COSTA  Rio Formoso, PE       02     2010, 2014   NaN
# 4               SILVIO COSTA  Rio Formoso, PE       02     2010, 2014   NaN

# %%
depts = tb_federais[tb_federais["Mandatos"] == max_mandatos_federais]["Deputados federais eleitos"].unique()
depts
# Out:
# array(['INOCÊNCIO OLIVEIRA'], dtype=object)

# %%
df_reembolso_pe_top1 = df_reembolso_pe[df_reembolso_pe["txNomeParlamentar"].isin(depts)]
df_reembolso_pe_top1.head()
# Out:
#        txNomeParlamentar          cpf ideCadastro nuCarteiraParlamentar  \
# 2694  INOCÊNCIO OLIVEIRA  00177601434       74421                   145
# 2695  INOCÊNCIO OLIVEIRA  00177601434       74421                   145
# 2696  INOCÊNCIO OLIVEIRA  00177601434       74421                   145
# 2697  INOCÊNCIO OLIVEIRA  00177601434       74421                   145
# 2698  INOCÊNCIO OLIVEIRA  00177601434       74421                   145
#
#      nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 2694          2011   PE        PR             54          1
# 2695          2011   PE        PR             54          1
# 2696          2011   PE        PR             54          1
# 2697          2011   PE        PR             54          1
# 2698          2011   PE        PR             54          5
#
#                                            txtDescricao  \
# 2694  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2695  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2696  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2697  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2698               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
#
#      numEspecificacaoSubCota txtDescricaoEspecificacao  \
# 2694                       0                       NaN
# 2695                       0                       NaN
# 2696                       0                       NaN
# 2697                       0                       NaN
# 2698                       0                       NaN
#
#                                 txtFornecedor          txtCNPJCPF txtNumero  \
# 2694           BOMPREÇO SUP. DO NORDESTE LTDA  130.045.100/2517-3    122077
# 2695           BOMPREÇO SUP. DO NORDESTE LTDA  130.045.100/2517-3    132378
# 2696             CIL COM. DE INFORMÁTICA LTDA  240.736.940/0031-7      5101
# 2697  PAPELARIA ABC COMÉRCIO E INDÚSTRIA LTDA  005.402.520/0010-3     21058
# 2698                     Brasilia Degravações  118.131.220/0011-3       234
#
#      indTipoDocumento           datEmissao  vlrDocumento vlrGlosa  vlrLiquido  \
# 2694                0  2013-04-14T00:00:00        128.90        0      128.90
# 2695                0  2013-08-21T00:00:00        135.00        0      135.00
# 2696                0  2013-06-12T00:00:00        237.10      8.6      228.50
# 2697                0  2013-09-16T00:00:00        441.48        0      441.48
# 2698                0  2013-05-07T00:00:00        600.00        0      600.00
#
#      numMes numAno numParcela txtPassageiro txtTrecho  numLote  \
# 2694      4   2013          0           NaN       NaN  1022295
# 2695      8   2013          0           NaN       NaN  1058974
# 2696      6   2013          0           NaN       NaN  1052316
# 2697      9   2013          0           NaN       NaN  1057814
# 2698      4   2013          0           NaN       NaN  1027112
#
#      numRessarcimento  vlrRestituicao nuDeputadoId ideDocumento  urlDocumento  \
# 2694              NaN             NaN          107      5082552           NaN
# 2695              NaN             NaN          107      5223377           NaN
# 2696              NaN             NaN          107      5197726           NaN
# 2697              NaN             NaN          107      5218857           NaN
# 2698              NaN             NaN          107      5101790           NaN
#
#      Deputados federais eleitos       Naturalidade Mandatos  \
# 2694         INOCÊNCIO OLIVEIRA  Serra Talhada, PE       10
# 2695         INOCÊNCIO OLIVEIRA  Serra Talhada, PE       10
# 2696         INOCÊNCIO OLIVEIRA  Serra Talhada, PE       10
# 2697         INOCÊNCIO OLIVEIRA  Serra Talhada, PE       10
# 2698         INOCÊNCIO OLIVEIRA  Serra Talhada, PE       10
#
#                                          Ano da eleição Notas
# 2694  1974, 1978, 1982, 1986, 1990, 1994, 1998, 2002...   NaN
# 2695  1974, 1978, 1982, 1986, 1990, 1994, 1998, 2002...   NaN
# 2696  1974, 1978, 1982, 1986, 1990, 1994, 1998, 2002...   NaN
# 2697  1974, 1978, 1982, 1986, 1990, 1994, 1998, 2002...   NaN
# 2698  1974, 1978, 1982, 1986, 1990, 1994, 1998, 2002...   NaN

# %%
df_reembolso_pe_top1.groupby("txtDescricao")["vlrLiquido"].sum().sort_values(ascending=False).to_frame()
# Out:
#                                                     vlrLiquido
# txtDescricao
# PASSAGEM AÉREA - RPA                                 122823.05
# SERVIÇOS POSTAIS                                      55387.06
# TELEFONIA                                             26670.31
# DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                  25848.00
# MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE P...      933.88

# %%
f"Valor total gasto R$ {df_reembolso_pe_top1['vlrLiquido'].sum()}"
# Out:
# 'Valor total gasto R$ 231662.30000000002'

# %%
df_reembolso_pe.groupby("txtDescricao")["vlrLiquido"].mean().sort_values(ascending=False).to_frame()
# Out:
#                                                      vlrLiquido
# txtDescricao
# LOCAÇÃO OU FRETAMENTO DE EMBARCAÇÕES                8300.000000
# DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                6518.972477
# CONSULTORIAS, PESQUISAS E TRABALHOS TÉCNICOS.       6463.478981
# LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES       3811.140833
# LOCAÇÃO DE VEÍCULOS AUTOMOTORES OU FRETAMENTO D...  2142.855244
# MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE P...   983.494604
# PASSAGEM AÉREA - REEMBOLSO                           617.215253
# ASSINATURA DE PUBLICAÇÕES                            464.693529
# PASSAGEM AÉREA - RPA                                 407.499985
# COMBUSTÍVEIS E LUBRIFICANTES.                        278.467183
# HOSPEDAGEM ,EXCETO DO PARLAMENTAR NO DISTRITO F...   265.675978
# SERVIÇO DE SEGURANÇA PRESTADO POR EMPRESA ESPEC...   263.595652
# TELEFONIA                                            259.837632
# SERVIÇOS POSTAIS                                     110.486256
# FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR            66.095962
# SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO             33.875532

# %%
df_reembolso_pe["vlrLiquido"].mean()
# Out:
# 528.9465786283891

# %%
f"Valor medio gasto pelos parlamentares de PE R$ {df_reembolso_pe['vlrLiquido'].mean()}"
# Out:
# 'Valor medio gasto pelos parlamentares de PE R$ 528.9465786283891'
