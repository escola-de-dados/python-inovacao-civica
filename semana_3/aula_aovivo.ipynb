# %% [markdown]
# # Formas de baixar os csvs

# %%
import requests
from zipfile import ZipFile

# fazendo o download do conteúdo do arquivo
url = "http://www.camara.leg.br/cotas/Ano-2018.csv.zip"
r = requests.get(url)

# como acessar o conteúdo do arquivo?
# r.content

# como verificar se a requisição deu certo?
# r.status (lista de status)

file = open("Ano-2018.csv.zip", "wb")
file.write(r.content)
file.close()

zip_file = ZipFile(f"Ano-2018.csv.zip", "r")
zip_file.extract(member=f"Ano-2018.csv", path=f"reembolso-2018")
zip_file.close()

# %% [markdown]
# ## podemos ler os arquivos de outro jeito

# %% [markdown]
# precisamos ler e escrever como `bytes objects` sem nenhum `deecoding`

# %%
with open("Ano-2018-teste.csv.zip", "w") as file:
    file.write(r.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7779/2291717715.py in <module>
#       1 with open("Ano-2018-teste.csv.zip", "w") as file:
# ----> 2     file.write(r.content)
#
# TypeError: write() argument must be str, not bytes

# %% [markdown]
# o `with` é legal porque:
#
# * ele é um gerenciador de contexto (`context manager`)
# * ele gerencia sozinho toda fase de configuração para trabalhar com um arquivo (`setup`) e o encerramento dessa seção de trabalho (`teardown`)

# %%
with open("Ano-2018-teste.csv.zip", "wb") as file:
    file.write(r.content)

# %%
with ZipFile(f"Ano-2018.csv.zip", "r") as zip_file:
    zip_file.extract(member=f"Ano-2018.csv", path=f"reembolso-2018")

# %% [markdown]
# Utilizando o pandas diretamente

# %%
import pandas as pd
pd.set_option("display.max_columns", None)

df = pd.read_csv(
    "http://www.camara.leg.br/cotas/Ano-2018.csv.zip",
    sep=";",
    compression="zip"
)

df.head()
# Out:
#   txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LID.GOV-CD  NaN          NaN                    NaN           2015
# 1        LID.GOV-CD  NaN          NaN                    NaN           2015
# 2        LID.GOV-CD  NaN          NaN                    NaN           2015
# 3        LID.GOV-CD  NaN          NaN                    NaN           2015
# 4        LID.GOV-CD  NaN          NaN                    NaN           2015
#
#   sgUF sgPartido  codLegislatura  numSubCota  \
# 0  NaN       NaN              55          13
# 1  NaN       NaN              55          13
# 2  NaN       NaN              55          13
# 3  NaN       NaN              55          13
# 4  NaN       NaN              55          13
#
#                                  txtDescricao  numEspecificacaoSubCota  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 2  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 3  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
# 4  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0
#
#   txtDescricaoEspecificacao                        txtFornecedor  \
# 0                       NaN     BISCOITOS CASEIROS HOMONNAI LTDA
# 1                       NaN  BONNA COMERCIAL DE ALIMENTOS EIRELI
# 2                       NaN            CAFE DO FLAVIO EIRELLI-ME
# 3                       NaN            CAFE DO FLAVIO EIRELLI-ME
# 4                       NaN               CRISTIANE FERREIRA EPP
#
#            txtCNPJCPF txtNumero  indTipoDocumento           datEmissao  \
# 0  046.448.200/0017-7     10473                 4  2018-12-20T00:00:00
# 1  106.385.970/0015-8       105                 4  2018-02-21T00:00:00
# 2  248.825.670/0010-5     40792                 4  2018-09-05T00:00:00
# 3  248.825.670/0010-5     42181                 4  2018-10-16T00:00:00
# 4  037.139.030/0010-8       409                 4  2018-02-05T00:00:00
#
#    vlrDocumento  vlrGlosa  vlrLiquido  numMes  numAno  numParcela  \
# 0        454.41       0.0      454.41      12    2018           0
# 1        242.90       0.0      242.90       2    2018           0
# 2         79.00       0.0       79.00       9    2018           0
# 3        207.00       0.0      207.00      10    2018           0
# 4         98.75       0.0       98.75       2    2018           0
#
#   txtPassageiro txtTrecho  numLote  numRessarcimento  vlrRestituicao  \
# 0           NaN       NaN  1550817               NaN             NaN
# 1           NaN       NaN  1467117               NaN             NaN
# 2           NaN       NaN  1527969               NaN             NaN
# 3           NaN       NaN  1532624               NaN             NaN
# 4           NaN       NaN  1460984               NaN             NaN
#
#    nuDeputadoId  ideDocumento  \
# 0          2812       6728796
# 1          2812       6508293
# 2          2812       6666881
# 3          2812       6681167
# 4          2812       6491959
#
#                                         urlDocumento
# 0  https://www.camara.leg.br/cota-parlamentar/not...
# 1  https://www.camara.leg.br/cota-parlamentar/not...
# 2  https://www.camara.leg.br/cota-parlamentar/not...
# 3  https://www.camara.leg.br/cota-parlamentar/not...
# 4  https://www.camara.leg.br/cota-parlamentar/not...

# %% [markdown]
# # Qual a importância de passar o tipo das colunas na hora de leitura do csv?
#
# O pandas pode errar quando tenta determinar o tipo das variáveis (ele lê todos os dados antes), para facilitar isso, passamos o tipo das colunas.

# %%
df.dtypes
# Out:
# txNomeParlamentar             object
# cpf                          float64
# ideCadastro                  float64
# nuCarteiraParlamentar        float64
# nuLegislatura                  int64
# sgUF                          object
# sgPartido                     object
# codLegislatura                 int64
# numSubCota                     int64
# txtDescricao                  object
# numEspecificacaoSubCota        int64
# txtDescricaoEspecificacao     object
# txtFornecedor                 object
# txtCNPJCPF                    object
# txtNumero                     object
# indTipoDocumento               int64
# datEmissao                    object
# vlrDocumento                 float64
# vlrGlosa                     float64
# vlrLiquido                   float64
# numMes                         int64
# numAno                         int64
# numParcela                     int64
# txtPassageiro                 object
# txtTrecho                     object
# numLote                        int64
# numRessarcimento             float64
# vlrRestituicao               float64
# nuDeputadoId                   int64
# ideDocumento                   int64
# urlDocumento                  object
# dtype: object

# %%
DTYPE = {
    "txNomeParlamentar": str,
    "cpf": str,
    "ideCadastro": str,
    "nuCarteiraParlamentar": str,
    "nuLegislatura": str,
    "sgUF": str,
    "sgPartido": str,
    "codLegislatura": str,
    "numSubCota": str,
    "txtDescricao": str,
    "numEspecificacaoSubCota": str,
    "txtDescricaoEspecificacao": str,
    "txtFornecedor": str,
    "txtCNPJCPF": str,
    "txtNumero": str,
    "indTipoDocumento": str,
    "datEmissao": str,
    "vlrDocumento": float,
    "vlrGlosa": str,
    "vlrLiquido": float,
    "numMes": str,
    "numAno": str,
    "numParcela": str,
    "txtPassageiro": str,
    "txtTrecho": str,
    "numLote": str,
    "numRessarcimento": str,
    "nuDeputadoId": str,
    "ideDocumento": str,
}

df_reembolso = pd.read_csv(
    "http://www.camara.leg.br/cotas/Ano-2018.csv.zip",
    sep=";",
    compression="zip",
    dtype=DTYPE
)

# %%
df_reembolso.dtypes
# Out:
# txNomeParlamentar             object
# cpf                           object
# ideCadastro                   object
# nuCarteiraParlamentar         object
# nuLegislatura                 object
# sgUF                          object
# sgPartido                     object
# codLegislatura                object
# numSubCota                    object
# txtDescricao                  object
# numEspecificacaoSubCota       object
# txtDescricaoEspecificacao     object
# txtFornecedor                 object
# txtCNPJCPF                    object
# txtNumero                     object
# indTipoDocumento              object
# datEmissao                    object
# vlrDocumento                 float64
# vlrGlosa                      object
# vlrLiquido                   float64
# numMes                        object
# numAno                        object
# numParcela                    object
# txtPassageiro                 object
# txtTrecho                     object
# numLote                       object
# numRessarcimento              object
# vlrRestituicao               float64
# nuDeputadoId                  object
# ideDocumento                  object
# urlDocumento                  object
# dtype: object

# %% [markdown]
# # Funções úteis

# %% [markdown]
# ## `astype()`

# %%
df_reembolso.astype("object").dtypes
# Out:
# txNomeParlamentar            object
# cpf                          object
# ideCadastro                  object
# nuCarteiraParlamentar        object
# nuLegislatura                object
# sgUF                         object
# sgPartido                    object
# codLegislatura               object
# numSubCota                   object
# txtDescricao                 object
# numEspecificacaoSubCota      object
# txtDescricaoEspecificacao    object
# txtFornecedor                object
# txtCNPJCPF                   object
# txtNumero                    object
# indTipoDocumento             object
# datEmissao                   object
# vlrDocumento                 object
# vlrGlosa                     object
# vlrLiquido                   object
# numMes                       object
# numAno                       object
# numParcela                   object
# txtPassageiro                object
# txtTrecho                    object
# numLote                      object
# numRessarcimento             object
# vlrRestituicao               object
# nuDeputadoId                 object
# ideDocumento                 object
# urlDocumento                 object
# dtype: object

# %%
df_reembolso.astype({"vlrRestituicao": "object"}).dtypes
# Out:
# txNomeParlamentar             object
# cpf                           object
# ideCadastro                   object
# nuCarteiraParlamentar         object
# nuLegislatura                 object
# sgUF                          object
# sgPartido                     object
# codLegislatura                object
# numSubCota                    object
# txtDescricao                  object
# numEspecificacaoSubCota       object
# txtDescricaoEspecificacao     object
# txtFornecedor                 object
# txtCNPJCPF                    object
# txtNumero                     object
# indTipoDocumento              object
# datEmissao                    object
# vlrDocumento                 float64
# vlrGlosa                      object
# vlrLiquido                   float64
# numMes                        object
# numAno                        object
# numParcela                    object
# txtPassageiro                 object
# txtTrecho                     object
# numLote                       object
# numRessarcimento              object
# vlrRestituicao                object
# nuDeputadoId                  object
# ideDocumento                  object
# urlDocumento                  object
# dtype: object

# %% [markdown]
# ## `to_datetime()`

# %%
df_reembolso.datEmissao.dtypes
# Out:
# dtype('O')

# %%
df_reembolso.datEmissao
# Out:
# 0         2018-12-20T00:00:00
# 1         2018-02-21T00:00:00
# 2         2018-09-05T00:00:00
# 3         2018-10-16T00:00:00
# 4         2018-02-05T00:00:00
#                  ...
# 292749                    NaN
# 292750    2018-12-20T00:00:00
# 292751    2018-12-20T00:00:00
# 292752    2019-01-08T00:00:00
# 292753    2018-12-28T00:00:00
# Name: datEmissao, Length: 292754, dtype: object

# %%
pd.to_datetime(df_reembolso.datEmissao, format="%Y-%m-%d")
# Out:
# 0        2018-12-20
# 1        2018-02-21
# 2        2018-09-05
# 3        2018-10-16
# 4        2018-02-05
#             ...
# 292749          NaT
# 292750   2018-12-20
# 292751   2018-12-20
# 292752   2019-01-08
# 292753   2018-12-28
# Name: datEmissao, Length: 292754, dtype: datetime64[ns]

# %%
df_reembolso_2 = pd.read_csv(
    "http://www.camara.leg.br/cotas/Ano-2019.csv.zip",
    sep=";",
    compression="zip",
    dtype=DTYPE,
    parse_dates=["datEmissao"]
)

# %%
df_reembolso_2.datEmissao
# Out:
# 0        2018-12-20
# 1        2018-02-21
# 2        2018-09-05
# 3        2018-10-16
# 4        2018-02-05
#             ...
# 292749          NaT
# 292750   2018-12-20
# 292751   2018-12-20
# 292752   2019-01-08
# 292753   2018-12-28
# Name: datEmissao, Length: 292754, dtype: datetime64[ns]

# %% [markdown]
# ### coisinhas legais com datas

# %%
df_reembolso_2.datEmissao.dt

# %%
df_reembolso_2.datEmissao.dt.day_name()
# Out:
# 0          Thursday
# 1         Wednesday
# 2         Wednesday
# 3           Tuesday
# 4            Monday
#             ...
# 292749          NaN
# 292750     Thursday
# 292751     Thursday
# 292752      Tuesday
# 292753       Friday
# Name: datEmissao, Length: 292754, dtype: object

# %%
df_reembolso_2.datEmissao.dt.dayofweek
# Out:
# 0         3.0
# 1         2.0
# 2         2.0
# 3         1.0
# 4         0.0
#          ...
# 292749    NaN
# 292750    3.0
# 292751    3.0
# 292752    1.0
# 292753    4.0
# Name: datEmissao, Length: 292754, dtype: float64

# %%
df_reembolso_2.datEmissao.dt.year
# Out:
# 0         2018.0
# 1         2018.0
# 2         2018.0
# 3         2018.0
# 4         2018.0
#            ...
# 292749       NaN
# 292750    2018.0
# 292751    2018.0
# 292752    2019.0
# 292753    2018.0
# Name: datEmissao, Length: 292754, dtype: float64

# %%
df_reembolso_2.datEmissao.dt.month
# Out:
# 0         12.0
# 1          2.0
# 2          9.0
# 3         10.0
# 4          2.0
#           ...
# 292749     NaN
# 292750    12.0
# 292751    12.0
# 292752     1.0
# 292753    12.0
# Name: datEmissao, Length: 292754, dtype: float64

# %% [markdown]
# ### range de datas

# %% [markdown]
# `.loc` -> Access a group of rows and columns by label(s) or a boolean array.
#
# .loc[] is primarily label based, but may also be used with a boolean array.

# %%
df_reembolso_2.loc[
    (df_reembolso_2.datEmissao >= "2018-01-01")
    & (df_reembolso_2.datEmissao <= "2018-04-30")
]
# Out:
#           txNomeParlamentar          cpf ideCadastro nuCarteiraParlamentar  \
# 1                LID.GOV-CD          NaN         NaN                   NaN
# 4                LID.GOV-CD          NaN         NaN                   NaN
# 5                LID.GOV-CD          NaN         NaN                   NaN
# 6                LID.GOV-CD          NaN         NaN                   NaN
# 7                LID.GOV-CD          NaN         NaN                   NaN
# ...                     ...          ...         ...                   ...
# 292296  PROF. GEDEÃO AMORIM  01196820287      200153                   609
# 292311  PROF. GEDEÃO AMORIM  01196820287      200153                   609
# 292312  PROF. GEDEÃO AMORIM  01196820287      200153                   609
# 292313  PROF. GEDEÃO AMORIM  01196820287      200153                   609
# 292314  PROF. GEDEÃO AMORIM  01196820287      200153                   609
#
#        nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 1               2015  NaN       NaN             55         13
# 4               2015  NaN       NaN             55         13
# 5               2015  NaN       NaN             55         13
# 6               2015  NaN       NaN             55         13
# 7               2015  NaN       NaN             55         13
# ...              ...  ...       ...            ...        ...
# 292296          2015   AM       MDB             55        999
# 292311          2015   AM       MDB             55        999
# 292312          2015   AM       MDB             55        999
# 292313          2015   AM       MDB             55        999
# 292314          2015   AM       MDB             55        999
#
#                                       txtDescricao numEspecificacaoSubCota  \
# 1       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 4       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 5       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 6       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 7       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# ...                                            ...                     ...
# 292296                        PASSAGEM AÉREA - RPA                       0
# 292311                        PASSAGEM AÉREA - RPA                       0
# 292312                        PASSAGEM AÉREA - RPA                       0
# 292313                        PASSAGEM AÉREA - RPA                       0
# 292314                        PASSAGEM AÉREA - RPA                       0
#
#        txtDescricaoEspecificacao                        txtFornecedor  \
# 1                            NaN  BONNA COMERCIAL DE ALIMENTOS EIRELI
# 4                            NaN               CRISTIANE FERREIRA EPP
# 5                            NaN               CRISTIANE FERREIRA EPP
# 6                            NaN               CRISTIANE FERREIRA EPP
# 7                            NaN               CRISTIANE FERREIRA EPP
# ...                          ...                                  ...
# 292296                       NaN                      Cia Aérea - TAM
# 292311                       NaN                      Cia Aérea - TAM
# 292312                       NaN                      Cia Aérea - TAM
# 292313                       NaN                      Cia Aérea - TAM
# 292314                       NaN                      Cia Aérea - TAM
#
#                 txtCNPJCPF                 txtNumero indTipoDocumento  \
# 1       106.385.970/0015-8                       105                4
# 4       037.139.030/0010-8                       409                4
# 5       037.139.030/0010-8                       414                4
# 6       037.139.030/0010-8                       420                4
# 7       037.139.030/0010-8                       440                4
# ...                    ...                       ...              ...
# 292296  020.128.620/0016-0  Bilhete: 957-2164.438917                0
# 292311  020.128.620/0016-0      Comp-957-2161.584478                0
# 292312  020.128.620/0016-0      Comp-957-2161.584479                0
# 292313  020.128.620/0016-0      Comp-957-2161.584481                0
# 292314  020.128.620/0016-0      Comp-957-2161.584483                0
#
#        datEmissao  vlrDocumento vlrGlosa  vlrLiquido numMes numAno numParcela  \
# 1      2018-02-21        242.90        0      242.90      2   2018          0
# 4      2018-02-05         98.75        0       98.75      2   2018          0
# 5      2018-03-13        127.83        0      127.83      3   2018          0
# 6      2018-04-03        118.15        0      118.15      4   2018          0
# 7      2018-04-24        123.17        0      123.17      4   2018          0
# ...           ...           ...      ...         ...    ...    ...        ...
# 292296 2018-04-26       1904.17        0     1904.17      4   2018          0
# 292311 2018-02-08      -1169.17        0    -1169.17      2   2018          0
# 292312 2018-02-08       -475.93        0     -475.93      2   2018          0
# 292313 2018-02-08       -442.93        0     -442.93      2   2018          0
# 292314 2018-02-08       -442.93        0     -442.93      2   2018          0
#
#               txtPassageiro txtTrecho  numLote numRessarcimento  \
# 1                       NaN       NaN  1467117              NaN
# 4                       NaN       NaN  1460984              NaN
# 5                       NaN       NaN  1473970              NaN
# 6                       NaN       NaN  1480990              NaN
# 7                       NaN       NaN  1487485              NaN
# ...                     ...       ...      ...              ...
# 292296  PROF. GEDEÃO AMORIM   MAO/BSB        0                0
# 292311  PROF. GEDEÃO AMORIM   MAO/BSB        0                0
# 292312  PROF. GEDEÃO AMORIM   BSB/MAO        0                0
# 292313  PROF. GEDEÃO AMORIM   BSB/MAO        0                0
# 292314  PROF. GEDEÃO AMORIM   BSB/MAO        0                0
#
#         vlrRestituicao nuDeputadoId ideDocumento  \
# 1                  NaN         2812      6508293
# 4                  NaN         2812      6491959
# 5                  NaN         2812      6525989
# 6                  NaN         2812      6544380
# 7                  NaN         2812      6561122
# ...                ...          ...          ...
# 292296             NaN         3177      1601020
# 292311             NaN         3177      1616800
# 292312             NaN         3177      1616803
# 292313             NaN         3177      1619090
# 292314             NaN         3177      1619091
#
#                                              urlDocumento
# 1       https://www.camara.leg.br/cota-parlamentar/not...
# 4       https://www.camara.leg.br/cota-parlamentar/not...
# 5       https://www.camara.leg.br/cota-parlamentar/not...
# 6       https://www.camara.leg.br/cota-parlamentar/not...
# 7       https://www.camara.leg.br/cota-parlamentar/not...
# ...                                                   ...
# 292296                                                NaN
# 292311                                                NaN
# 292312                                                NaN
# 292313                                                NaN
# 292314                                                NaN
#
# [101079 rows x 31 columns]

# %%
df_reembolso_2.set_index("datEmissao").loc["2018-01-01":"2018-04-30"]
# Out:
#               txNomeParlamentar          cpf ideCadastro  \
# datEmissao
# 2018-02-21           LID.GOV-CD          NaN         NaN
# 2018-02-05           LID.GOV-CD          NaN         NaN
# 2018-03-13           LID.GOV-CD          NaN         NaN
# 2018-04-03           LID.GOV-CD          NaN         NaN
# 2018-04-24           LID.GOV-CD          NaN         NaN
# ...                         ...          ...         ...
# 2018-04-26  PROF. GEDEÃO AMORIM  01196820287      200153
# 2018-02-08  PROF. GEDEÃO AMORIM  01196820287      200153
# 2018-02-08  PROF. GEDEÃO AMORIM  01196820287      200153
# 2018-02-08  PROF. GEDEÃO AMORIM  01196820287      200153
# 2018-02-08  PROF. GEDEÃO AMORIM  01196820287      200153
#
#            nuCarteiraParlamentar nuLegislatura sgUF sgPartido codLegislatura  \
# datEmissao
# 2018-02-21                   NaN          2015  NaN       NaN             55
# 2018-02-05                   NaN          2015  NaN       NaN             55
# 2018-03-13                   NaN          2015  NaN       NaN             55
# 2018-04-03                   NaN          2015  NaN       NaN             55
# 2018-04-24                   NaN          2015  NaN       NaN             55
# ...                          ...           ...  ...       ...            ...
# 2018-04-26                   609          2015   AM       MDB             55
# 2018-02-08                   609          2015   AM       MDB             55
# 2018-02-08                   609          2015   AM       MDB             55
# 2018-02-08                   609          2015   AM       MDB             55
# 2018-02-08                   609          2015   AM       MDB             55
#
#            numSubCota                                txtDescricao  \
# datEmissao
# 2018-02-21         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 2018-02-05         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 2018-03-13         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 2018-04-03         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# 2018-04-24         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# ...               ...                                         ...
# 2018-04-26        999                        PASSAGEM AÉREA - RPA
# 2018-02-08        999                        PASSAGEM AÉREA - RPA
# 2018-02-08        999                        PASSAGEM AÉREA - RPA
# 2018-02-08        999                        PASSAGEM AÉREA - RPA
# 2018-02-08        999                        PASSAGEM AÉREA - RPA
#
#            numEspecificacaoSubCota txtDescricaoEspecificacao  \
# datEmissao
# 2018-02-21                       0                       NaN
# 2018-02-05                       0                       NaN
# 2018-03-13                       0                       NaN
# 2018-04-03                       0                       NaN
# 2018-04-24                       0                       NaN
# ...                            ...                       ...
# 2018-04-26                       0                       NaN
# 2018-02-08                       0                       NaN
# 2018-02-08                       0                       NaN
# 2018-02-08                       0                       NaN
# 2018-02-08                       0                       NaN
#
#                                   txtFornecedor          txtCNPJCPF  \
# datEmissao
# 2018-02-21  BONNA COMERCIAL DE ALIMENTOS EIRELI  106.385.970/0015-8
# 2018-02-05               CRISTIANE FERREIRA EPP  037.139.030/0010-8
# 2018-03-13               CRISTIANE FERREIRA EPP  037.139.030/0010-8
# 2018-04-03               CRISTIANE FERREIRA EPP  037.139.030/0010-8
# 2018-04-24               CRISTIANE FERREIRA EPP  037.139.030/0010-8
# ...                                         ...                 ...
# 2018-04-26                      Cia Aérea - TAM  020.128.620/0016-0
# 2018-02-08                      Cia Aérea - TAM  020.128.620/0016-0
# 2018-02-08                      Cia Aérea - TAM  020.128.620/0016-0
# 2018-02-08                      Cia Aérea - TAM  020.128.620/0016-0
# 2018-02-08                      Cia Aérea - TAM  020.128.620/0016-0
#
#                            txtNumero indTipoDocumento  vlrDocumento vlrGlosa  \
# datEmissao
# 2018-02-21                       105                4        242.90        0
# 2018-02-05                       409                4         98.75        0
# 2018-03-13                       414                4        127.83        0
# 2018-04-03                       420                4        118.15        0
# 2018-04-24                       440                4        123.17        0
# ...                              ...              ...           ...      ...
# 2018-04-26  Bilhete: 957-2164.438917                0       1904.17        0
# 2018-02-08      Comp-957-2161.584478                0      -1169.17        0
# 2018-02-08      Comp-957-2161.584479                0       -475.93        0
# 2018-02-08      Comp-957-2161.584481                0       -442.93        0
# 2018-02-08      Comp-957-2161.584483                0       -442.93        0
#
#             vlrLiquido numMes numAno numParcela        txtPassageiro  \
# datEmissao
# 2018-02-21      242.90      2   2018          0                  NaN
# 2018-02-05       98.75      2   2018          0                  NaN
# 2018-03-13      127.83      3   2018          0                  NaN
# 2018-04-03      118.15      4   2018          0                  NaN
# 2018-04-24      123.17      4   2018          0                  NaN
# ...                ...    ...    ...        ...                  ...
# 2018-04-26     1904.17      4   2018          0  PROF. GEDEÃO AMORIM
# 2018-02-08    -1169.17      2   2018          0  PROF. GEDEÃO AMORIM
# 2018-02-08     -475.93      2   2018          0  PROF. GEDEÃO AMORIM
# 2018-02-08     -442.93      2   2018          0  PROF. GEDEÃO AMORIM
# 2018-02-08     -442.93      2   2018          0  PROF. GEDEÃO AMORIM
#
#            txtTrecho  numLote numRessarcimento  vlrRestituicao nuDeputadoId  \
# datEmissao
# 2018-02-21       NaN  1467117              NaN             NaN         2812
# 2018-02-05       NaN  1460984              NaN             NaN         2812
# 2018-03-13       NaN  1473970              NaN             NaN         2812
# 2018-04-03       NaN  1480990              NaN             NaN         2812
# 2018-04-24       NaN  1487485              NaN             NaN         2812
# ...              ...      ...              ...             ...          ...
# 2018-04-26   MAO/BSB        0                0             NaN         3177
# 2018-02-08   MAO/BSB        0                0             NaN         3177
# 2018-02-08   BSB/MAO        0                0             NaN         3177
# 2018-02-08   BSB/MAO        0                0             NaN         3177
# 2018-02-08   BSB/MAO        0                0             NaN         3177
#
#            ideDocumento                                       urlDocumento
# datEmissao
# 2018-02-21      6508293  https://www.camara.leg.br/cota-parlamentar/not...
# 2018-02-05      6491959  https://www.camara.leg.br/cota-parlamentar/not...
# 2018-03-13      6525989  https://www.camara.leg.br/cota-parlamentar/not...
# 2018-04-03      6544380  https://www.camara.leg.br/cota-parlamentar/not...
# 2018-04-24      6561122  https://www.camara.leg.br/cota-parlamentar/not...
# ...                 ...                                                ...
# 2018-04-26      1601020                                                NaN
# 2018-02-08      1616800                                                NaN
# 2018-02-08      1616803                                                NaN
# 2018-02-08      1619090                                                NaN
# 2018-02-08      1619091                                                NaN
#
# [101114 rows x 30 columns]

# %% [markdown]
# # O caso do `vlrLiquido`
#
# Aqui nós podemos ver que temos valores negativos. Esse valores são referentes a bilhetes de compensação, bilhete de compensação é o bilhete aéreo não voado, que foi reembolsado à Câmara dos Deputados. Portanto, o valor relativo aos bilhetes compensados (não voados) são reembolsados/devolvidos à Casa, deduzindo-se as taxas de cancelamento e de no-show, de acordo com as regras tarifárias da companhia aérea respectiva.
#
# Esse crédito pode voltar para a conta corrente do parlamentar mantida na companhia aérea para ser utilizado com nova emissão de passagem aérea ou poderá voltar para a CEAP do respectivo parlamentar, ficando disponível para utilização com as demais despesas.

# %%
df_reembolso.vlrLiquido.min()
# Out:
# -4906.0

# %%
df_reembolso.vlrLiquido.describe()
# Out:
# count    292754.000000
# mean        735.865371
# std        2481.009069
# min       -4906.000000
# 25%          50.000000
# 50%         192.170000
# 75%         671.170000
# max      130000.000000
# Name: vlrLiquido, dtype: float64

# %%
negative_documents = df_reembolso_2[df_reembolso_2["vlrLiquido"] < 0]

len(negative_documents)
# Out:
# 10739

# %%
negative_documents['ideDocumento']
# Out:
# 920       1640498
# 1759         2203
# 1763         2275
# 1766         1660
# 1772          313
#            ...
# 289164    1708904
# 289176    1723048
# 289177    1724703
# 289178    1723049
# 289318    1724810
# Name: ideDocumento, Length: 10739, dtype: object

# %%
positive_documents = df_reembolso_2[
    (df_reembolso_2['ideDocumento'].isin(negative_documents['ideDocumento']))
    & 
    (df_reembolso_2["vlrLiquido"] > 0)
]
positive_documents.head()
# Out:
#      txNomeParlamentar          cpf ideCadastro nuCarteiraParlamentar  \
# 1758     Fausto Pinato  28022995819       66828                   355
# 1762     Fausto Pinato  28022995819       66828                   355
# 1765     Fausto Pinato  28022995819       66828                   355
# 1771     Fausto Pinato  28022995819       66828                   355
# 3113           Bacelar  10626409500       69871                   184
#
#      nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 1758          2019   SP        PP             56        998
# 1762          2019   SP        PP             56        998
# 1765          2019   SP        PP             56        998
# 1771          2019   SP        PP             56        998
# 3113          2019   BA        PV             56        998
#
#                  txtDescricao numEspecificacaoSubCota  \
# 1758  PASSAGEM AÉREA - SIGEPA                       0
# 1762  PASSAGEM AÉREA - SIGEPA                       0
# 1765  PASSAGEM AÉREA - SIGEPA                       0
# 1771  PASSAGEM AÉREA - SIGEPA                       0
# 3113  PASSAGEM AÉREA - SIGEPA                       0
#
#      txtDescricaoEspecificacao txtFornecedor txtCNPJCPF txtNumero  \
# 1758                       NaN           GOL        NaN    GLLN8G
# 1762                       NaN           GOL        NaN    KSKZ8B
# 1765                       NaN           GOL        NaN    LM8MGG
# 1771                       NaN           GOL        NaN    VRF7MH
# 3113                       NaN           GOL        NaN    CR6F4R
#
#      indTipoDocumento          datEmissao  vlrDocumento vlrGlosa  vlrLiquido  \
# 1758                0 2019-11-20 12:00:00       1386.50        0     1386.50
# 1762                0 2019-11-21 12:00:00       1791.57        0     1791.57
# 1765                0 2019-10-21 12:00:00       1277.57        0     1277.57
# 1771                0 2019-07-17 12:00:00       1432.88        0     1432.88
# 3113                0 2019-10-10 12:00:00       1046.13        0     1046.13
#
#      numMes numAno numParcela                txtPassageiro txtTrecho numLote  \
# 1758     11   2019          0            Fausto Ruy Pinato   BSB/CGH       0
# 1762     11   2019          0            Fausto Ruy Pinato   BSB/CGH       0
# 1765     10   2019          0     Roberto Holanda Craveiro   BSB/GRU       0
# 1771      7   2019          0            Fausto Ruy Pinato   SDU/BSB       0
# 3113     10   2019          0  JOAO CARLOS BACELAR BATISTA   SSA/BSB       0
#
#      numRessarcimento  vlrRestituicao nuDeputadoId ideDocumento urlDocumento
# 1758                0             NaN         2917         2203          NaN
# 1762                0             NaN         2917         2275          NaN
# 1765                0             NaN         2917         1660          NaN
# 1771                0             NaN         2917          313          NaN
# 3113                0             NaN         2985         1503          NaN

# %%
len(positive_documents)
# Out:
# 602

# %%
positive_documents.iloc[0].to_frame()
# Out:
#                                               1758
# txNomeParlamentar                    Fausto Pinato
# cpf                                    28022995819
# ideCadastro                                  66828
# nuCarteiraParlamentar                          355
# nuLegislatura                                 2019
# sgUF                                            SP
# sgPartido                                       PP
# codLegislatura                                  56
# numSubCota                                     998
# txtDescricao               PASSAGEM AÉREA - SIGEPA
# numEspecificacaoSubCota                          0
# txtDescricaoEspecificacao                      NaN
# txtFornecedor                                  GOL
# txtCNPJCPF                                     NaN
# txtNumero                                   GLLN8G
# indTipoDocumento                                 0
# datEmissao                     2019-11-20 12:00:00
# vlrDocumento                                1386.5
# vlrGlosa                                         0
# vlrLiquido                                  1386.5
# numMes                                          11
# numAno                                        2019
# numParcela                                       0
# txtPassageiro                    Fausto Ruy Pinato
# txtTrecho                                  BSB/CGH
# numLote                                          0
# numRessarcimento                                 0
# vlrRestituicao                                 NaN
# nuDeputadoId                                  2917
# ideDocumento                                  2203
# urlDocumento                                   NaN

# %%
sample = negative_documents[negative_documents.duplicated(subset = 'ideDocumento')].iloc[1] #, keep = {‘last’, ‘first’, ‘false’)

# %%
df_reembolso_2[df_reembolso_2['ideDocumento'] == sample['ideDocumento']]
# Out:
#      txNomeParlamentar          cpf ideCadastro nuCarteiraParlamentar  \
# 3134           Bacelar  10626409500       69871                   184
# 3135           Bacelar  10626409500       69871                   184
# 3136           Bacelar  10626409500       69871                   184
#
#      nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 3134          2019   BA        PV             56        998
# 3135          2019   BA        PV             56        998
# 3136          2019   BA        PV             56        998
#
#                  txtDescricao numEspecificacaoSubCota  \
# 3134  PASSAGEM AÉREA - SIGEPA                       0
# 3135  PASSAGEM AÉREA - SIGEPA                       0
# 3136  PASSAGEM AÉREA - SIGEPA                       0
#
#      txtDescricaoEspecificacao txtFornecedor txtCNPJCPF txtNumero  \
# 3134                       NaN           GOL        NaN    RMQ2VW
# 3135                       NaN           GOL        NaN    RMQ2VW
# 3136                       NaN           GOL        NaN    RMQ2VW
#
#      indTipoDocumento          datEmissao  vlrDocumento vlrGlosa  vlrLiquido  \
# 3134                0 2019-09-26 12:00:00       1423.46        0     1423.46
# 3135                0 2019-10-01 12:00:00        -25.00        0      -25.00
# 3136                0 2019-11-28 12:00:00      -1330.14        0    -1330.14
#
#      numMes numAno numParcela                txtPassageiro txtTrecho numLote  \
# 3134      9   2019          0  JOAO CARLOS BACELAR BATISTA   SSA/BSB       0
# 3135     10   2019          0  JOAO CARLOS BACELAR BATISTA   SSA/BSB       0
# 3136     11   2019          0  JOAO CARLOS BACELAR BATISTA   BSB/BSB       0
#
#      numRessarcimento  vlrRestituicao nuDeputadoId ideDocumento urlDocumento
# 3134                0             NaN         2985         1205          NaN
# 3135                0             NaN         2985         1205          NaN
# 3136                0             NaN         2985         1205          NaN
