# %%
import requests

url = f"http://www.camara.leg.br/cotas/Ano-2019.csv.zip"
r = requests.get(url)

# %%
# abrindo um arquivo no seu computador
file = open(f"Ano-2019.csv.zip", "wb")

# escrever o conteúdo
file.write(r.content)
file.close()

# %%
from zipfile import ZipFile

zip_file = ZipFile(f"Ano-2019.csv.zip", 'r')
zip_file.extract(member=f"Ano-2019.csv", path=f"reembolso-2019")
zip_file.close()

# %% [markdown]
# ### Aula 03: Lendo os dados com Pandas

# %%
import pandas as pd
pd.set_option('display.max_columns', None)


DTYPE = {
    'txNomeParlamentar': str,
    'ideCadastro': str,
    'nuCarteiraParlamentar': str,
    'nuLegislatura': str,
    'sgUF': str,
    'sgPartido': str,
    'codLegislatura': str,
    'numSubCota': str,
    'txtDescricao': str,
    'numEspecificacaoSubCota': str,
    'txtDescricaoEspecificacao': str,
    'txtFornecedor': str,
    'txtCNPJCPF': str,
    'txtNumero': str,
    'indTipoDocumento': str,
    'datEmissao': str,
    'vlrDocumento': float,
    'vlrGlosa': str,
    'vlrLiquido': float,
    'numMes': str,
    'numAno': str,
    'numParcela': str,
    'txtPassageiro': str,
    'txtTrecho': str,
    'numLote': str,
    'numRessarcimento': str,
    'nuDeputadoId': str,
    'ideDocumento': str,
}

df_reimbursements = pd.read_csv(
    "reembolso-2019/Ano-2019.csv", 
    delimiter=";", 
    dtype=DTYPE, 
    low_memory=False
)

# %% [markdown]
# #### transformações

# %%
df_reimbursements.fillna(value="Não se aplica").head()

# %%
df_reimbursements[df_reimbursements.sgPartido.isna()]

# %%
df_reimbursements[df_reimbursements['ideDocumento'].isnull()]

# %%
# df_reimbursements["ideCadastro"] = df_reimbursements["ideCadastro"].astype('string')

# %%
df_reimbursements["datEmissao"] = pd.to_datetime(
    df_reimbursements.datEmissao, 
    format='%Y-%m-%d'
)

# %%
df_reimbursements.datEmissao.min()
# Out:
# Timestamp('2018-06-13 00:00:00')

# %%
df_reimbursements.set_index("datEmissao").loc["2019-01-01":"2019-03-30"].shape
# Out:
# (59356, 30)

# %% [markdown]
# Outras coisas são possíveis, como encontrar o dia da semana de cada uma dessas datas, calcular a média móvel, calcular quantos anos se passaram, ou agrupar os dados por janelas de tempo.

# %% [markdown]
# #### completando, substituindo e reformatando

# %%
df_reimbursements["txtCNPJCPF"] = df_reimbursements["txtCNPJCPF"].str.replace(r'\D', '', regex=True)

# %%
# Este dado representa o tipo de documento do fiscal – 
# 0 (Zero), para Nota Fiscal; 1 (um), para Recibo; e 2, para Despesa no Exterior.

df_reimbursements.indTipoDocumento.unique()
# Out:
# array(['4', '0', '1', '3', '2'], dtype=object)

# %%
converters = {
    "0": 'nota_fiscal',
    "1": 'recibo',
    "2": 'despesa_exterior',
    "4": None
}

converters
# Out:
# {'0': 'nota_fiscal', '1': 'recibo', '2': 'despesa_exterior', '4': None}

# %%
df_reimbursements.indTipoDocumento.replace(converters, inplace=True)

# %%
df_reimbursements.indTipoDocumento.unique()
# Out:
# array([None, 'nota_fiscal', 'recibo', '3', 'despesa_exterior'],
#       dtype=object)

# %% [markdown]
# ### Atenção

# %%
keys = ['ideDocumento', 'numAno', 'nuDeputadoId']

# grouped = df_reimbursements.groupby(keys)["vlrLiquido"].agg("sum").rename(index="vlrLiquidoTotal").reset_index()
# grouped

# %%
df_reimbursements[df_reimbursements.numRessarcimento.isna()].shape
# Out:
# (177464, 31)

# %%
286886 * 0.05
# Out:
# 14344.300000000001

# %%
data_with_id = df_reimbursements[
    (~df_reimbursements[keys[0]].isnull()) &
    (~df_reimbursements[keys[1]].isnull()) &
    (~df_reimbursements[keys[2]].isnull())
]

# %%
grouped = df_reimbursements.groupby(keys)
len(grouped)
# Out:
# 260872

# %%
agg_net_values = grouped["vlrLiquido"].agg("sum").reset_index()

# %%
agg_net_values.shape
# Out:
# (260872, 4)

# %%
agg_data = pd.merge(
    df_reimbursements, 
    agg_net_values, 
    on=keys,
    suffixes=('', '_from_original')
)
agg_data.shape
# Out:
# (286886, 32)

# %%
agg_data.drop_duplicates(subset=keys, inplace=True)
agg_data.shape
# Out:
# (260872, 32)

# %%
df_reimbursements.dropna(subset=('vlrDocumento', 'numRessarcimento')).shape
# Out:
# (109422, 31)

# %%
df_reimbursements.shape
# Out:
# (286886, 31)

# %%
df_reimbursements = pd.merge(df_reimbursements, grouped, on=keys)
df_reimbursements.head(1)

# %%
df_reimbursements.groupby('txtNumero')["vlrLiquido"].agg("sum")
# Out:
# txtNumero
# *                 778.80
# -                3108.29
# -43BC9D7F7D7C      12.30
# -52B4F00B1507      12.30
# -6A7D2BE06302      12.30
#                   ...
# zwgemd            712.48
# ´RUTIH9QCR751       2.90
# ´T7VM1KLAC4LS       2.90
# Í3TBE8A2C7LG        2.90
# Ônibus La          49.90
# Name: vlrLiquido, Length: 214158, dtype: float64

# %%
df_reimbursements[(df_reimbursements.vlrLiquido < 0) & (df_reimbursements.txtNumero.duplicated())]
# Out:
#        txNomeParlamentar           cpf ideCadastro nuCarteiraParlamentar  \
# 2184    Iracema Portella  3.731164e+10       67138                   113
# 2185    Iracema Portella  3.731164e+10       67138                   113
# 2194    Iracema Portella  3.731164e+10       67138                   113
# 2690      Fábio Henrique  4.133020e+10       68720                   175
# 2692      Fábio Henrique  4.133020e+10       68720                   175
# ...                  ...           ...         ...                   ...
# 286586   Ricardo Pericar  8.648796e+10      211649                   543
# 286588   Ricardo Pericar  8.648796e+10      211649                   543
# 286590   Ricardo Pericar  8.648796e+10      211649                   543
# 286592   Ricardo Pericar  8.648796e+10      211649                   543
# 286595   Ricardo Pericar  8.648796e+10      211649                   543
#
#        nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 2184            2019   PI        PP             56        999
# 2185            2019   PI        PP             56        999
# 2194            2019   PI        PP             56        999
# 2690            2019   SE       PDT             56        999
# 2692            2019   SE       PDT             56        999
# ...              ...  ...       ...            ...        ...
# 286586          2019   RJ       PSL             56        999
# 286588          2019   RJ       PSL             56        999
# 286590          2019   RJ       PSL             56        999
# 286592          2019   RJ       PSL             56        999
# 286595          2019   RJ       PSL             56        999
#
#                 txtDescricao numEspecificacaoSubCota  \
# 2184    PASSAGEM AÉREA - RPA                       0
# 2185    PASSAGEM AÉREA - RPA                       0
# 2194    PASSAGEM AÉREA - RPA                       0
# 2690    PASSAGEM AÉREA - RPA                       0
# 2692    PASSAGEM AÉREA - RPA                       0
# ...                      ...                     ...
# 286586  PASSAGEM AÉREA - RPA                       0
# 286588  PASSAGEM AÉREA - RPA                       0
# 286590  PASSAGEM AÉREA - RPA                       0
# 286592  PASSAGEM AÉREA - RPA                       0
# 286595  PASSAGEM AÉREA - RPA                       0
#
#        txtDescricaoEspecificacao    txtFornecedor          txtCNPJCPF  \
# 2184                         NaN  Cia Aérea - GOL  075.756.510/0015-9
# 2185                         NaN  Cia Aérea - GOL  075.756.510/0015-9
# 2194                         NaN  Cia Aérea - GOL  075.756.510/0015-9
# 2690                         NaN  Cia Aérea - GOL  075.756.510/0015-9
# 2692                         NaN  Cia Aérea - GOL  075.756.510/0015-9
# ...                          ...              ...                 ...
# 286586                       NaN  Cia Aérea - GOL  075.756.510/0015-9
# 286588                       NaN  Cia Aérea - GOL  075.756.510/0015-9
# 286590                       NaN  Cia Aérea - GOL  075.756.510/0015-9
# 286592                       NaN  Cia Aérea - GOL  075.756.510/0015-9
# 286595                       NaN  Cia Aérea - GOL  075.756.510/0015-9
#
#           txtNumero indTipoDocumento           datEmissao  vlrDocumento  \
# 2184    Comp-NFRRYL                0  2019-04-30T00:00:00       -148.25
# 2185    Comp-NFRRYL                0  2019-05-02T00:00:00       -112.15
# 2194    Comp-XW3K4Q                0  2019-12-04T00:00:00      -1529.64
# 2690    Comp-GIF37P                0  2019-11-26T00:00:00        -25.89
# 2692    Comp-GRD26B                0  2019-07-02T00:00:00        -82.08
# ...             ...              ...                  ...           ...
# 286586  Comp-KM1ZUJ                0  2019-12-05T00:00:00        -15.00
# 286588  Comp-LMVZMT                0  2019-12-12T00:00:00        -15.00
# 286590  Comp-NMUTGT                0  2019-11-07T00:00:00        -15.00
# 286592  Comp-RK5QVP                0  2019-11-28T00:00:00        -15.00
# 286595  Comp-TM2YJJ                0  2019-10-01T00:00:00        -14.00
#
#        vlrGlosa  vlrLiquido numMes numAno numParcela     txtPassageiro  \
# 2184          0     -148.25      4   2019          0  Iracema Portella
# 2185          0     -112.15      5   2019          0  Iracema Portella
# 2194          0    -1529.64     12   2019          0  Iracema Portella
# 2690          0      -25.89     11   2019          0    Fábio Henrique
# 2692          0      -82.08      7   2019          0    Fábio Henrique
# ...         ...         ...    ...    ...        ...               ...
# 286586        0      -15.00     12   2019          0   Ricardo Pericar
# 286588        0      -15.00     12   2019          0   Ricardo Pericar
# 286590        0      -15.00     11   2019          0   Ricardo Pericar
# 286592        0      -15.00     11   2019          0   Ricardo Pericar
# 286595        0      -14.00     10   2019          0     MARCELO LEITE
#
#           txtTrecho numLote numRessarcimento  vlrRestituicao nuDeputadoId  \
# 2184        THE/GRU       0                0             NaN         2320
# 2185        THE/GRU       0                0             NaN         2320
# 2194        BSB/BSB       0                0             NaN         2320
# 2690        BSB/BSB       0                0             NaN         3240
# 2692        BSB/BSB       0                0             NaN         3240
# ...             ...     ...              ...             ...          ...
# 286586  SDU/BSB/SDU       0                0             NaN         3455
# 286588  SDU/BSB/SDU       0                0             NaN         3455
# 286590  SDU/BSB/SDU       0                0             NaN         3455
# 286592  SDU/BSB/SDU       0                0             NaN         3455
# 286595  SDU/BSB/SDU       0                0             NaN         3455
#
#        ideDocumento urlDocumento
# 2184        1660724          NaN
# 2185        1660727          NaN
# 2194        1715911          NaN
# 2690        1715097          NaN
# 2692        1679783          NaN
# ...             ...          ...
# 286586      1725047          NaN
# 286588      1725049          NaN
# 286590      1713136          NaN
# 286592      1715107          NaN
# 286595      1713140          NaN
#
# [1181 rows x 31 columns]

# %%
df_reimbursements[df_reimbursements.txtNumero.str.contains('NFRRYL')]
# Out:
#      txNomeParlamentar           cpf ideCadastro nuCarteiraParlamentar  \
# 2147  Iracema Portella  3.731164e+10       67138                   113
# 2183  Iracema Portella  3.731164e+10       67138                   113
# 2184  Iracema Portella  3.731164e+10       67138                   113
# 2185  Iracema Portella  3.731164e+10       67138                   113
#
#      nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 2147          2019   PI        PP             56        999
# 2183          2019   PI        PP             56        999
# 2184          2019   PI        PP             56        999
# 2185          2019   PI        PP             56        999
#
#               txtDescricao numEspecificacaoSubCota txtDescricaoEspecificacao  \
# 2147  PASSAGEM AÉREA - RPA                       0                       NaN
# 2183  PASSAGEM AÉREA - RPA                       0                       NaN
# 2184  PASSAGEM AÉREA - RPA                       0                       NaN
# 2185  PASSAGEM AÉREA - RPA                       0                       NaN
#
#         txtFornecedor          txtCNPJCPF        txtNumero indTipoDocumento  \
# 2147  Cia Aérea - GOL  075.756.510/0015-9  Bilhete: NFRRYL                0
# 2183  Cia Aérea - GOL  075.756.510/0015-9      Comp-NFRRYL                0
# 2184  Cia Aérea - GOL  075.756.510/0015-9      Comp-NFRRYL                0
# 2185  Cia Aérea - GOL  075.756.510/0015-9      Comp-NFRRYL                0
#
#                datEmissao  vlrDocumento vlrGlosa  vlrLiquido numMes numAno  \
# 2147  2019-04-22T00:00:00       2029.39        0     2029.39      4   2019
# 2183  2019-04-24T00:00:00       -108.60        0     -108.60      4   2019
# 2184  2019-04-30T00:00:00       -148.25        0     -148.25      4   2019
# 2185  2019-05-02T00:00:00       -112.15        0     -112.15      5   2019
#
#      numParcela     txtPassageiro txtTrecho numLote numRessarcimento  \
# 2147          0  Iracema Portella   BSB/THE       0                0
# 2183          0  Iracema Portella   THE/BSB       0                0
# 2184          0  Iracema Portella   THE/GRU       0                0
# 2185          0  Iracema Portella   THE/GRU       0                0
#
#       vlrRestituicao nuDeputadoId ideDocumento urlDocumento
# 2147             NaN         2320      1658810          NaN
# 2183             NaN         2320      1659005          NaN
# 2184             NaN         2320      1660724          NaN
# 2185             NaN         2320      1660727          NaN

# %%
df_reimbursements[
    (df_reimbursements.txNomeParlamentar == 'Iracema Portella') & 
    (df_reimbursements.txtDescricao == 'PASSAGEM AÉREA - RPA') & 
    (df_reimbursements.txtFornecedor == 'Cia Aérea - GOL') 
]
# Out:
#      txNomeParlamentar           cpf ideCadastro nuCarteiraParlamentar  \
# 1876  Iracema Portella  3.731164e+10       67138                   113
# 1877  Iracema Portella  3.731164e+10       67138                   113
# 1878  Iracema Portella  3.731164e+10       67138                   113
# 1879  Iracema Portella  3.731164e+10       67138                   113
# 1880  Iracema Portella  3.731164e+10       67138                   113
# ...                ...           ...         ...                   ...
# 2193  Iracema Portella  3.731164e+10       67138                   113
# 2194  Iracema Portella  3.731164e+10       67138                   113
# 2195  Iracema Portella  3.731164e+10       67138                   113
# 2196  Iracema Portella  3.731164e+10       67138                   113
# 2197  Iracema Portella  3.731164e+10       67138                   113
#
#      nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 1876          2015   PI        PP             55        999
# 1877          2015   PI        PP             55        999
# 1878          2015   PI        PP             55        999
# 1879          2015   PI        PP             55        999
# 1880          2015   PI        PP             55        999
# ...            ...  ...       ...            ...        ...
# 2193          2019   PI        PP             56        999
# 2194          2019   PI        PP             56        999
# 2195          2019   PI        PP             56        999
# 2196          2019   PI        PP             56        999
# 2197          2019   PI        PP             56        999
#
#               txtDescricao numEspecificacaoSubCota txtDescricaoEspecificacao  \
# 1876  PASSAGEM AÉREA - RPA                       0                       NaN
# 1877  PASSAGEM AÉREA - RPA                       0                       NaN
# 1878  PASSAGEM AÉREA - RPA                       0                       NaN
# 1879  PASSAGEM AÉREA - RPA                       0                       NaN
# 1880  PASSAGEM AÉREA - RPA                       0                       NaN
# ...                    ...                     ...                       ...
# 2193  PASSAGEM AÉREA - RPA                       0                       NaN
# 2194  PASSAGEM AÉREA - RPA                       0                       NaN
# 2195  PASSAGEM AÉREA - RPA                       0                       NaN
# 2196  PASSAGEM AÉREA - RPA                       0                       NaN
# 2197  PASSAGEM AÉREA - RPA                       0                       NaN
#
#         txtFornecedor          txtCNPJCPF        txtNumero indTipoDocumento  \
# 1876  Cia Aérea - GOL  075.756.510/0015-9  Bilhete: KGEVKV                0
# 1877  Cia Aérea - GOL  075.756.510/0015-9  Bilhete: MQP7YH                0
# 1878  Cia Aérea - GOL  075.756.510/0015-9  Bilhete: VHNMMF                0
# 1879  Cia Aérea - GOL  075.756.510/0015-9  Bilhete: XN8U5Q                0
# 1880  Cia Aérea - GOL  075.756.510/0015-9  Bilhete: YN8Q7Q                0
# ...               ...                 ...              ...              ...
# 2193  Cia Aérea - GOL  075.756.510/0015-9      Comp-XW3K4Q                0
# 2194  Cia Aérea - GOL  075.756.510/0015-9      Comp-XW3K4Q                0
# 2195  Cia Aérea - GOL  075.756.510/0015-9      Comp-ZIB2VF                0
# 2196  Cia Aérea - GOL  075.756.510/0015-9      Comp-ZMK4XZ                0
# 2197  Cia Aérea - GOL  075.756.510/0015-9      Comp-ZQ79FK                0
#
#                datEmissao  vlrDocumento vlrGlosa  vlrLiquido numMes numAno  \
# 1876  2019-01-30T00:00:00       1673.39        0     1673.39      1   2019
# 1877  2019-01-26T00:00:00       1300.17        0     1300.17      1   2019
# 1878  2019-01-31T00:00:00       1052.42        0     1052.42      1   2019
# 1879  2019-01-29T00:00:00       1930.17        0     1930.17      1   2019
# 1880  2019-01-26T00:00:00       1401.25        0     1401.25      1   2019
# ...                   ...           ...      ...         ...    ...    ...
# 2193  2019-09-27T00:00:00      -1315.92        0    -1315.92      9   2019
# 2194  2019-12-04T00:00:00      -1529.64        0    -1529.64     12   2019
# 2195  2019-03-01T00:00:00       -979.39        0     -979.39      3   2019
# 2196  2019-11-21T00:00:00      -1731.04        0    -1731.04     11   2019
# 2197  2019-03-29T00:00:00      -2010.39        0    -2010.39      3   2019
#
#      numParcela     txtPassageiro    txtTrecho numLote numRessarcimento  \
# 1876          0  Iracema Portella      BSB/THE       0                0
# 1877          0  Iracema Portella      CGH/SDU       0                0
# 1878          0  Iracema Portella  BSB/THE/BSB       0                0
# 1879          0  Iracema Portella      CGH/BSB       0                0
# 1880          0  Iracema Portella      GIG/CGH       0                0
# ...         ...               ...          ...     ...              ...
# 2193          0  Iracema Portella      THE/BSB       0                0
# 2194          0  Iracema Portella      BSB/BSB       0                0
# 2195          0  Iracema Portella      THE/BSB       0                0
# 2196          0  Iracema Portella      BSB/BSB       0                0
# 2197          0  Iracema Portella      BSB/BSB       0                0
#
#       vlrRestituicao nuDeputadoId ideDocumento urlDocumento
# 1876             NaN         2320      1638131          NaN
# 1877             NaN         2320      1637746          NaN
# 1878             NaN         2320      1638050          NaN
# 1879             NaN         2320      1638167          NaN
# 1880             NaN         2320      1637757          NaN
# ...              ...          ...          ...          ...
# 2193             NaN         2320      1702314          NaN
# 2194             NaN         2320      1715911          NaN
# 2195             NaN         2320      1645555          NaN
# 2196             NaN         2320      1714092          NaN
# 2197             NaN         2320      1653991          NaN
#
# [92 rows x 31 columns]

# %%
df_reimbursements.numRessarcimento.unique()
# Out:
# array([nan, '0'], dtype=object)

# %%
(df_reimbursements.txtNumero.isna()).sum()
# Out:
# 0

# %%
(df_reimbursements.numRessarcimento.isna()).sum()
# Out:
# 177464

# %%
df_reimbursements[df_reimbursements.ideDocumento.duplicated() & (df_reimbursements.ideDocumento > '0')].head()
# Out:
#       txNomeParlamentar           cpf ideCadastro nuCarteiraParlamentar  \
# 3054            Bacelar  1.062641e+10       69871                   184
# 3058            Bacelar  1.062641e+10       69871                   184
# 6542       Rubens Bueno  1.874642e+10       73466                   460
# 8765   Pompeo de Mattos  2.834689e+10       73486                   516
# 11757       Angela Amin  2.931672e+10       73696                   471
#
#       nuLegislatura sgUF sgPartido codLegislatura numSubCota  \
# 3054           2019   BA      PODE             56        998
# 3058           2019   BA      PODE             56        998
# 6542           2015   PR       PPS             55         13
# 8765           2019   RS       PDT             56         13
# 11757          2019   SC        PP             56         10
#
#                                      txtDescricao numEspecificacaoSubCota  \
# 3054                      PASSAGEM AÉREA - SIGEPA                       0
# 3058                      PASSAGEM AÉREA - SIGEPA                       0
# 6542   FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 8765   FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       0
# 11757                                   TELEFONIA                       0
#
#       txtDescricaoEspecificacao                   txtFornecedor  \
# 3054                        NaN                             GOL
# 3058                        NaN                             GOL
# 6542                        NaN  RESTAURANTE MADERO CABRAL LTDA
# 8765                        NaN                       Point 235
# 11757                       NaN                       CLARO S.A
#
#                txtCNPJCPF   txtNumero indTipoDocumento           datEmissao  \
# 3054                  NaN      NMS13D                0  2019-11-26T12:00:00
# 3058                  NaN      RMQ2VW                0  2019-11-28T12:00:00
# 6542   130.023.500/0013-9      210060                4  2019-01-28T00:00:00
# 8765   094.267.310/0017-8      000169                0  2019-08-18T00:00:00
# 11757  404.325.440/1916-6  0001173359                0  2019-04-17T00:00:00
#
#        vlrDocumento vlrGlosa  vlrLiquido numMes numAno numParcela  \
# 3054          32.13        0       32.13     11   2019          0
# 3058        1330.14        0     1330.14     11   2019          0
# 6542          74.80        0        0.00      1   2019          0
# 8765          15.00        0        0.00      8   2019          0
# 11757        258.72        0      102.26      4   2019          0
#
#                      txtPassageiro txtTrecho  numLote numRessarcimento  \
# 3054   JOAO CARLOS BACELAR BATISTA   BSB/BSB        0                0
# 3058   JOAO CARLOS BACELAR BATISTA   BSB/BSB        0                0
# 6542                           NaN       NaN  1557819              NaN
# 8765                           NaN       NaN  1627523              NaN
# 11757                          NaN       NaN  1590486              NaN
#
#        vlrRestituicao nuDeputadoId ideDocumento  \
# 3054              NaN         2985         1504
# 3058              NaN         2985         1205
# 6542              6.8          831      6746139
# 8765             15.0         1458      6905386
# 11757             NaN          835      6820670
#
#                                             urlDocumento
# 3054                                                 NaN
# 3058                                                 NaN
# 6542   http://camara.leg.br/cota-parlamentar/nota-fis...
# 8765   https://www.camara.leg.br/cota-parlamentar/doc...
# 11757                                                NaN

# %%
df_reimbursements[df_reimbursements.numRessarcimento.isna()].loc[1].urlDocumento
# Out:
# 'http://camara.leg.br/cota-parlamentar/nota-fiscal-eletronica?ideDocumentoFiscal=6769606'
