# %%
# import requests

# url = "http://www.camara.leg.br/cotas/Ano-2019.csv.zip"
# r = requests.get(url)

# %%
# file = open("Ano-2019.csv.zip", "wb")
# file.write(r.content)
# file.close()

# %%
# from zipfile import ZipFile

# zip_file = ZipFile("Ano-2019.csv.zip", 'r')

# %%
# zip_file.extract(member="Ano-2019.csv", path="reembolso-2019")
# Out:
# 'reembolso-2019/Ano-2019.csv'

# %%
# zip_file.close()

# %%
import pandas as pd
# Out:
# /Users/gabriela/Development/Contrib/okb/python-inovacao-civica/notebooks/venv/lib/python3.7/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
DTYPE = {
    'txNomeParlamentar': str,
    'ideCadastro': str,
    'nuCarteiraParlamentar': str,
    'nuLegislatura': str,
    'sgUF': str,
    'sgPartido': str,
    'codLegislatura': str,
    'numSubCota': str,
    'txtDescricao': str,
    'numEspecificacaoSubCota': str,
    'txtDescricaoEspecificacao': str,
    'txtFornecedor': str,
    'txtCNPJCPF': str,
    'txtNumero': str,
    'indTipoDocumento': str,
    'datEmissao': str,
    'vlrDocumento': float,
    'vlrGlosa': str,
    'vlrLiquido': float,
    'numMes': str,
    'numAno': str,
    'numParcela': str,
    'txtPassageiro': str,
    'txtTrecho': str,
    'numLote': str,
    'numRessarcimento': str,
    'nuDeputadoId': str,
    'ideDocumento': str,
}

df_reembolso = pd.read_csv("reembolso-2019/Ano-2019.csv", sep=";", dtype=DTYPE)

# %%
df_reembolso.head(1)
# Out:
#   txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LID.GOV-CD  NaN          NaN                    NaN           2015
#
#   sgUF sgPartido  codLegislatura  numSubCota  \
# 0  NaN       NaN              55          13
#
#                                  txtDescricao  ...  numAno numParcela  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
#
#   txtPassageiro txtTrecho  numLote  numRessarcimento vlrRestituicao  \
# 0           NaN       NaN  1554246               NaN            NaN
#
#    nuDeputadoId  ideDocumento  \
# 0          2812       6738121
#
#                                         urlDocumento
# 0  http://camara.leg.br/cota-parlamentar/nota-fis...
#
# [1 rows x 31 columns]

# %%
df_reembolso.sample(10)
# Out:
#         txNomeParlamentar           cpf ideCadastro nuCarteiraParlamentar  \
# 175570    Dr. Luiz Ovando  5.134552e+09      204351                   435
# 203361  Alcides Rodrigues  1.362098e+10      204413                   419
# 257754      Tiago Mitraud  7.529511e+09      204519                   264
# 260680       Rosana Valle  1.085178e+10      204525                   388
# 31332    Maria do Rosário  4.898937e+10       74398                   508
# 67897       Flaviano Melo  3.325180e+10      141434                    54
# 253693      Guiga Peixoto  4.434957e+09      204513                   363
# 171914     Merlong Solano  1.389182e+10      188097                   540
# 204011     Aroldo Martins  2.107484e+10      204414                   444
# 49240           Cacá Leão  7.975357e+10       93083                   193
#
#        nuLegislatura sgUF     sgPartido codLegislatura numSubCota  \
# 175570          2019   MS           PSL             56          1
# 203361          2019   GO      PATRIOTA             56          3
# 257754          2019   MG          NOVO             56        123
# 260680          2019   SP           PSB             56        122
# 31332           2019   RS            PT             56        122
# 67897           2019   AC           MDB             56        119
# 253693          2019   SP           PSL             56        122
# 171914          2019   PI            PT             56          3
# 204011          2019   PR  REPUBLICANOS             56          3
# 49240           2019   BA            PP             56        999
#
#                                              txtDescricao  ... numAno  \
# 175570  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  ...   2019
# 203361                      COMBUSTÍVEIS E LUBRIFICANTES.  ...   2019
# 257754        PASSAGENS TERRESTRES, MARÍTIMAS OU FLUVIAIS  ...   2019
# 260680          SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO  ...   2019
# 31332           SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO  ...   2019
# 67897                  LOCAÇÃO OU FRETAMENTO DE AERONAVES  ...   2019
# 253693          SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO  ...   2019
# 171914                      COMBUSTÍVEIS E LUBRIFICANTES.  ...   2019
# 204011                      COMBUSTÍVEIS E LUBRIFICANTES.  ...   2019
# 49240                                PASSAGEM AÉREA - RPA  ...   2019
#
#        numParcela txtPassageiro txtTrecho  numLote numRessarcimento  \
# 175570          0           NaN       NaN  1650986              NaN
# 203361          0           NaN       NaN  1581335              NaN
# 257754          0           NaN       NaN  1598738              NaN
# 260680          0           NaN       NaN  1613464              NaN
# 31332           0           NaN       NaN  1647423              NaN
# 67897           0           NaN       NaN  1627394              NaN
# 253693          0           NaN       NaN  1621683              NaN
# 171914          0           NaN       NaN  1582215              NaN
# 204011          0           NaN       NaN  1575813              NaN
# 49240           0     Cacá Leão   BSB/BSB        0                0
#
#        vlrRestituicao  nuDeputadoId ideDocumento  \
# 175570            NaN          3393      6958354
# 203361            NaN          3409      6798345
# 257754            NaN          3288      6837258
# 260680            NaN          3281      6871903
# 31332             NaN          1605      6949978
# 67897             NaN          1836      6905041
# 253693            NaN          3410      6892753
# 171914            NaN          3121      6800533
# 204011            NaN          3361      6784638
# 49240             NaN          2897      1718364
#
#                                              urlDocumento
# 175570  https://www.camara.leg.br/cota-parlamentar/doc...
# 203361  http://camara.leg.br/cota-parlamentar/nota-fis...
# 257754  https://www.camara.leg.br/cota-parlamentar/doc...
# 260680  https://www.camara.leg.br/cota-parlamentar/doc...
# 31332   https://www.camara.leg.br/cota-parlamentar/doc...
# 67897   https://www.camara.leg.br/cota-parlamentar/doc...
# 253693  https://www.camara.leg.br/cota-parlamentar/doc...
# 171914  http://camara.leg.br/cota-parlamentar/nota-fis...
# 204011  http://camara.leg.br/cota-parlamentar/nota-fis...
# 49240                                                 NaN
#
# [10 rows x 31 columns]

# %%
filtro_partido_null = df_reembolso.cpf.isna()
# filtro_partido_null = df_reembolso['sg-Partido'].isna()

df_reembolso.loc[filtro_partido_null, "cpf"] = "0000000"

# %%
df_reembolso.head()
# Out:
#   txNomeParlamentar      cpf ideCadastro nuCarteiraParlamentar nuLegislatura  \
# 0        LID.GOV-CD  0000000         NaN                   NaN          2015
# 1        LID.GOV-CD  0000000         NaN                   NaN          2019
# 2        LID.GOV-CD  0000000         NaN                   NaN          2019
# 3        LID.GOV-CD  0000000         NaN                   NaN          2019
# 4        LID.GOV-CD  0000000         NaN                   NaN          2019
#
#   sgUF sgPartido codLegislatura numSubCota  \
# 0  NaN       NaN             55         13
# 1  NaN       NaN             56         13
# 2  NaN       NaN             56         13
# 3  NaN       NaN             56         13
# 4  NaN       NaN             56         13
#
#                                  txtDescricao  ... numAno numParcela  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019          0
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019          0
# 2  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019          0
# 3  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019          0
# 4  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019          0
#
#   txtPassageiro txtTrecho  numLote numRessarcimento vlrRestituicao  \
# 0           NaN       NaN  1554246              NaN            NaN
# 1           NaN       NaN  1570078              NaN            NaN
# 2           NaN       NaN  1570503              NaN            NaN
# 3           NaN       NaN  1579375              NaN            NaN
# 4           NaN       NaN  1590980              NaN            NaN
#
#    nuDeputadoId ideDocumento  \
# 0          2812      6738121
# 1          2812      6769606
# 2          2812      6771099
# 3          2812      6793690
# 4          2812      6821674
#
#                                         urlDocumento
# 0  http://camara.leg.br/cota-parlamentar/nota-fis...
# 1  http://camara.leg.br/cota-parlamentar/nota-fis...
# 2  http://camara.leg.br/cota-parlamentar/nota-fis...
# 3  http://camara.leg.br/cota-parlamentar/nota-fis...
# 4  http://camara.leg.br/cota-parlamentar/nota-fis...
#
# [5 rows x 31 columns]

# %%
# df_reembolso["datEmissao"]

# %%
df_reembolso["datEmissao"] = pd.to_datetime(df_reembolso["datEmissao"], format="%Y-%m-%d")

# %%
# df_reembolso.set_index("datEmissao").loc["2019-01-01":"2019-04-30"]
# wd = {
#     0: "seg",
#     1: "ter",
# }

# df_reembolso["datEmissao"].dt.dayofweek < 5
# Out:
# 0         2.0
# 1         0.0
# 2         0.0
# 3         3.0
# 4         1.0
#          ...
# 288761    2.0
# 288762    1.0
# 288763    2.0
# 288764    NaN
# 288765    4.0
# Name: datEmissao, Length: 288766, dtype: float64

# %%
df_reembolso["txtCNPJCPF"] = df_reembolso["txtCNPJCPF"].str.replace(r'\D', '', regex=True)

# %%
df_reembolso["txtCNPJCPF"]
# Out:
# 0         03713903000108
# 1         03713903000108
# 2         03713903000108
# 3         03713903000108
# 4         03713903000108
#                ...
# 288761    02012862000160
# 288762       00722772700
# 288763    02012862000160
# 288764    00000000000006
# 288765    09602675000185
# Name: txtCNPJCPF, Length: 288766, dtype: object

# %%
df_reembolso.txtDescricao.value_counts(normalize=True).sort_values(ascending=False).to_frame().head(10)
# Out:
#                                                     txtDescricao
# PASSAGEM AÉREA - RPA                                    0.281726
# COMBUSTÍVEIS E LUBRIFICANTES.                           0.224282
# SERVIÇO DE TÁXI, PEDÁGIO E ESTACIONAMENTO               0.109282
# MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE P...      0.076235
# TELEFONIA                                               0.075771
# FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR              0.061444
# SERVIÇOS POSTAIS                                        0.051810
# DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                    0.037906
# LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES           0.021744
# HOSPEDAGEM ,EXCETO DO PARLAMENTAR NO DISTRITO F...      0.019320

# %%
df_reembolso["vlrLiquido"].describe()
# Out:
# count    288766.000000
# mean        712.196406
# std        2091.952095
# min       -7821.200000
# 25%          48.980000
# 50%         184.825000
# 75%         689.935000
# max      145140.000000
# Name: vlrLiquido, dtype: float64

# %%
# filtro_vlr_max = df_reembolso.vlrLiquido == df_reembolso.vlrLiquido.max()

filtro_cat_alim = df_reembolso.txtDescricao == 'FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR'
filtro_vlr_max = df_reembolso.vlrLiquido > 5000

df_reembolso[(filtro_cat_alim) & (filtro_vlr_max)]
# Out:
#                                     txNomeParlamentar      cpf ideCadastro  \
# 152  LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL  0000000         NaN
# 159  LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL  0000000         NaN
# 160  LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL  0000000         NaN
# 164  LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL  0000000         NaN
# 168  LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL  0000000         NaN
# 264                        LIDERANÇA DO PROGRESSISTAS  0000000         NaN
# 265                        LIDERANÇA DO PROGRESSISTAS  0000000         NaN
# 266                        LIDERANÇA DO PROGRESSISTAS  0000000         NaN
# 267                                  LIDERANÇA DO PSD  0000000         NaN
# 283                                  LIDERANÇA DO PSD  0000000         NaN
#
#     nuCarteiraParlamentar nuLegislatura sgUF sgPartido codLegislatura  \
# 152                   NaN          2019  NaN       NaN             56
# 159                   NaN          2019  NaN       NaN             56
# 160                   NaN          2019  NaN       NaN             56
# 164                   NaN          2019  NaN       NaN             56
# 168                   NaN          2019  NaN       NaN             56
# 264                   NaN          2019  NaN       NaN             56
# 265                   NaN          2019  NaN       NaN             56
# 266                   NaN          2019  NaN       NaN             56
# 267                   NaN          2015  NaN       NaN             55
# 283                   NaN          2019  NaN       NaN             56
#
#     numSubCota                                txtDescricao  ... numAno  \
# 152         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019
# 159         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019
# 160         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019
# 164         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019
# 168         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019
# 264         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019
# 265         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019
# 266         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019
# 267         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019
# 283         13  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...   2019
#
#     numParcela txtPassageiro txtTrecho  numLote numRessarcimento  \
# 152          0           NaN       NaN  1661111              NaN
# 159          0           NaN       NaN  1650383              NaN
# 160          0           NaN       NaN  1581569              NaN
# 164          0           NaN       NaN  1609922              NaN
# 168          0           NaN       NaN  1636965              NaN
# 264          0           NaN       NaN  1651228              NaN
# 265          0           NaN       NaN  1655704              NaN
# 266          0           NaN       NaN  1663508              NaN
# 267          0           NaN       NaN  1558264              NaN
# 283          0           NaN       NaN  1616327              NaN
#
#     vlrRestituicao  nuDeputadoId ideDocumento  \
# 152            NaN          2865      6981848
# 159            NaN          2865      6956990
# 160            NaN          2865      6798895
# 164            NaN          2865      6864494
# 168            NaN          2865      6926450
# 264            NaN          3461      6959055
# 265            NaN          3461      6969841
# 266            NaN          3461      6987099
# 267            NaN          2725      6747304
# 283            NaN          2725      6879754
#
#                                           urlDocumento
# 152  http://camara.leg.br/cota-parlamentar/nota-fis...
# 159  http://camara.leg.br/cota-parlamentar/nota-fis...
# 160  http://camara.leg.br/cota-parlamentar/nota-fis...
# 164  http://camara.leg.br/cota-parlamentar/nota-fis...
# 168  http://camara.leg.br/cota-parlamentar/nota-fis...
# 264  https://www.camara.leg.br/cota-parlamentar/doc...
# 265  https://www.camara.leg.br/cota-parlamentar/doc...
# 266  https://www.camara.leg.br/cota-parlamentar/doc...
# 267  https://www.camara.leg.br/cota-parlamentar/doc...
# 283  https://www.camara.leg.br/cota-parlamentar/doc...
#
# [10 rows x 31 columns]

# %%
df_reembolso.groupby(['sgPartido', 'sgUF', 'txNomeParlamentar'])["vlrLiquido"].sum().sort_values(ascending=False).to_frame()
# Out:
#                                   vlrLiquido
# sgPartido sgUF txNomeParlamentar
# PP        RR   Hiran Gonçalves     542487.76
# MDB       AC   Jéssica Sales       537322.05
# PDT       RS   Afonso Motta        537270.79
# PCdoB     AC   Perpétua Almeida    536138.75
# MDB       AC   Flaviano Melo       520071.45
# ...                                      ...
# PSDB      MS   Geraldo Resende          1.40
# PV        MA   SARNEY FILHO             1.25
# DEM       MS   MANDETTA                 0.60
# PCdoB     PE   LUCIANA SANTOS           0.49
# PROS      RJ   FELIPE BORNIER       -1675.06
#
# [851 rows x 1 columns]

# %%
pd.options.display.float_format = '{:,.2f}'.format

df_reembolso.groupby(['txtCNPJCPF', 'txtFornecedor'])['vlrLiquido'].sum().sort_values(
    ascending=False
).to_frame()[:10]
# Out:
#                                                                  vlrLiquido
# txtCNPJCPF     txtFornecedor
# 02012862000160 Cia Aérea - TAM                                24,702,018.72
# 07575651000159 Cia Aérea - GOL                                22,007,574.87
# 09296295000160 Cia Aérea - AZUL                                6,440,608.61
# 07319323000191 PANTANAL VEÍCULOS LTDA                          2,181,274.52
# 02012862000160 TAM LINHAS AEREAS S/A.                          1,172,126.78
# 02575829000148 Cia Aérea - AVIANCA                             1,136,178.65
# 23721017000133 T2 COMUNICACAO, VIDEO E PRODUCOES EIRELI - EPP  1,097,334.00
# 00000000000001 CELULAR FUNCIONAL                                 872,853.43
# 02558157000162 TELEFÔNICA BRASIL S.A. VIVO                       860,813.15
# 02610235000120 DMD Gestão Administrativa LTDA - ME               805,000.00

# %%
df_reembolso[['txtCNPJCPF', 'txtFornecedor']]
# Out:
#             txtCNPJCPF                          txtFornecedor
# 0       03713903000108                 CRISTIANE FERREIRA EPP
# 1       03713903000108                 CRISTIANE FERREIRA EPP
# 2       03713903000108                 CRISTIANE FERREIRA EPP
# 3       03713903000108                 CRISTIANE FERREIRA EPP
# 4       03713903000108  PANIFICADORA FERREIRA NETO LTDA - EPP
# ...                ...                                    ...
# 288761  02012862000160                        Cia Aérea - TAM
# 288762     00722772700             LUIZ FELIPE GOULART MARINS
# 288763  02012862000160                         LATAM AIRLINES
# 288764  00000000000006                                  RAMAL
# 288765  09602675000185              CARRY SERVIÇOS E LOCAÇÕES
#
# [288766 rows x 2 columns]
