# %% [markdown]
# # Escola de Dados - Python para inovação cívica
# ## Módulo 1: Por dentro do python
#
# - [Aula 5](#Aula-5:-Pacotes)
# - [Aula 6](#Aula-6:-Método-readcsv)
# - [Aula 7](#Aula-7:-Carregando-tabelas)
#
#
# ### Aula 5: Pacotes
#
# Instalaremos todos os pacotes que usaremos nesse módulo; Pandas, Matplotlib, Numpy, Jupiter Widgets e Pandas Profiling. Descomente as linhas abaixo (remova o # do início dos comandos) para instalar.

# %%
# pip install pandas

# %%
# pip install matplotlib

# %%
# pip install numpy

# %%
# pip install ipywidgets

# %%
# pip install pandas-profiling

# %% [markdown]
# A instalação é só realizada 1 vez, mas a importação das bibliotecas deve ocorrer no inicío do código, como na próxima linha:

# %%
import pandas as pd

# %% [markdown]
# ### Aula 6: Método readcsv
# Vamos aprender a ler arquivos do tipo CSV e converter para dataframe Pandas.
#
# Os dados que usaremos nesse notebook pode ser encontrado em: [Candidatos - 2022](https://dadosabertos.tse.jus.br/dataset/candidatos-2022)

# %%
candidaturas_pe = pd.read_csv('base_dados/consulta_cand_2022_AP.csv', sep=';', encoding='latin_1')

# %%
# o comando abaixo retira a limitação da quantidade de colunas impressa na tela

pd.options.display.max_columns = None

# %%
candidaturas_pe.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO
# 0  13/05/2023   19:32:48         2022                2  ELEIÇÃO ORDINÁRIA  \
# 1  13/05/2023   19:32:48         2022                2  ELEIÇÃO ORDINÁRIA
# 2  13/05/2023   19:32:48         2022                2  ELEIÇÃO ORDINÁRIA
# 3  13/05/2023   19:32:48         2022                2  ELEIÇÃO ORDINÁRIA
# 4  13/05/2023   19:32:48         2022                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO
# 0         1         546  Eleições Gerais Estaduais 2022  02/10/2022  \
# 1         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 2         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 3         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 4         1         546  Eleições Gerais Estaduais 2022  02/10/2022
#
#   TP_ABRANGENCIA SG_UF SG_UE  NM_UE  CD_CARGO           DS_CARGO
# 0       ESTADUAL    AP    AP  AMAPÁ         7  DEPUTADO ESTADUAL  \
# 1       ESTADUAL    AP    AP  AMAPÁ         7  DEPUTADO ESTADUAL
# 2       ESTADUAL    AP    AP  AMAPÁ         7  DEPUTADO ESTADUAL
# 3       ESTADUAL    AP    AP  AMAPÁ         6   DEPUTADO FEDERAL
# 4       ESTADUAL    AP    AP  AMAPÁ         7  DEPUTADO ESTADUAL
#
#    SQ_CANDIDATO  NR_CANDIDATO                          NM_CANDIDATO
# 0   30001604008         12125        MARIA DORACY SANTOS DE FREITAS  \
# 1   30001695670         28778              FLAVIA NASCIMENTO FARIAS
# 2   30001608275         40000              LUIZ ARMANDO VIDAL RAMOS
# 3   30001611414          1422  EDUARDO HENRIQUE ANDRADE DE SIQUEIRA
# 4   30001600727         11190           JOSÉ WILLIAN DA SILVA LEITE
#
#        NM_URNA_CANDIDATO NM_SOCIAL_CANDIDATO  NR_CPF_CANDIDATO
# 0          DORA FREITAS               #NULO#       37384805287  \
# 1          FLAVIA FARIAS              #NULO#       96359390272
# 2             PROF. LUIZ              #NULO#       52805336291
# 3           EDU SIQUEIRA              #NULO#       20565372220
# 4  TENENTE WILLIAN LEITE              #NULO#       72956828215
#
#          NM_EMAIL  CD_SITUACAO_CANDIDATURA DS_SITUACAO_CANDIDATURA
# 0  NÃO DIVULGÁVEL                       12                    APTO  \
# 1  NÃO DIVULGÁVEL                       12                    APTO
# 2  NÃO DIVULGÁVEL                       12                    APTO
# 3  NÃO DIVULGÁVEL                       12                    APTO
# 4  NÃO DIVULGÁVEL                       12                    APTO
#
#    CD_DETALHE_SITUACAO_CAND DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO
# 0                         2                 DEFERIDO  PARTIDO ISOLADO  \
# 1                         2                 DEFERIDO  PARTIDO ISOLADO
# 2                         2                 DEFERIDO  PARTIDO ISOLADO
# 3                         2                 DEFERIDO  PARTIDO ISOLADO
# 4                         2                 DEFERIDO  PARTIDO ISOLADO
#
#    NR_PARTIDO SG_PARTIDO                                NM_PARTIDO
# 0          12        PDT           PARTIDO DEMOCRÁTICO TRABALHISTA  \
# 1          28       PRTB  PARTIDO RENOVADOR TRABALHISTA BRASILEIRO
# 2          40        PSB             PARTIDO SOCIALISTA BRASILEIRO
# 3          14        PTB            PARTIDO TRABALHISTA BRASILEIRO
# 4          11         PP                             PROGRESSISTAS
#
#    NR_FEDERACAO NM_FEDERACAO SG_FEDERACAO DS_COMPOSICAO_FEDERACAO
# 0            -1       #NULO#       #NULO#                  #NULO#  \
# 1            -1       #NULO#       #NULO#                  #NULO#
# 2            -1       #NULO#       #NULO#                  #NULO#
# 3            -1       #NULO#       #NULO#                  #NULO#
# 4            -1       #NULO#       #NULO#                  #NULO#
#
#    SQ_COLIGACAO     NM_COLIGACAO DS_COMPOSICAO_COLIGACAO  CD_NACIONALIDADE
# 0   30001681219  PARTIDO ISOLADO                     PDT                 1  \
# 1   30001684595  PARTIDO ISOLADO                    PRTB                 1
# 2   30001681366  PARTIDO ISOLADO                     PSB                 1
# 3   30001681574  PARTIDO ISOLADO                     PTB                 1
# 4   30001681062  PARTIDO ISOLADO                      PP                 1
#
#   DS_NACIONALIDADE SG_UF_NASCIMENTO  CD_MUNICIPIO_NASCIMENTO
# 0  BRASILEIRA NATA               PA                       -3  \
# 1  BRASILEIRA NATA               AP                       -3
# 2  BRASILEIRA NATA               AP                       -3
# 3  BRASILEIRA NATA               PA                       -3
# 4  BRASILEIRA NATA               AP                       -3
#
#   NM_MUNICIPIO_NASCIMENTO DT_NASCIMENTO  NR_IDADE_DATA_POSSE
# 0                    AFUÁ    25/10/1966                   56  \
# 1                  MACAPÁ    12/08/1992                   30
# 2                  MACAPÁ    16/01/1988                   35
# 3                  ÓBIDOS    18/08/1966                   56
# 4                  MACAPÁ    07/06/1983                   39
#
#    NR_TITULO_ELEITORAL_CANDIDATO  CD_GENERO  DS_GENERO  CD_GRAU_INSTRUCAO
# 0                      331912500          4   FEMININO                  6  \
# 1                     5761022569          4   FEMININO                  7
# 2                     5042022500          2  MASCULINO                  8
# 3                     6100181309          2  MASCULINO                  6
# 4                     3507052500          2  MASCULINO                  8
#
#        DS_GRAU_INSTRUCAO  CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_COR_RACA
# 0  ENSINO MÉDIO COMPLETO                1     SOLTEIRO(A)            3  \
# 1    SUPERIOR INCOMPLETO                1     SOLTEIRO(A)            3
# 2      SUPERIOR COMPLETO                1     SOLTEIRO(A)            3
# 3  ENSINO MÉDIO COMPLETO                3       CASADO(A)            1
# 4      SUPERIOR COMPLETO                3       CASADO(A)            1
#
#   DS_COR_RACA  CD_OCUPACAO                                     DS_OCUPACAO
# 0       PARDA          581                                    DONA DE CASA  \
# 1       PARDA          931  ESTUDANTE, BOLSISTA, ESTAGIÁRIO E ASSEMELHADOS
# 2       PARDA          142                    PROFESSOR DE ENSINO SUPERIOR
# 3      BRANCA          257                                      EMPRESÁRIO
# 4      BRANCA          233                                POLICIAL MILITAR
#
#    VR_DESPESA_MAX_CAMPANHA  CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO ST_REELEICAO
# 0               1270629.01                 5         SUPLENTE            N  \
# 1               1270629.01                 4       NÃO ELEITO            N
# 2               1270629.01                 4       NÃO ELEITO            N
# 3               3176572.53                 4       NÃO ELEITO            N
# 4               1270629.01                 5         SUPLENTE            N
#
#   ST_DECLARAR_BENS  NR_PROTOCOLO_CANDIDATURA          NR_PROCESSO
# 0                S                        -1  6002701620226030000  \
# 1                N                        -1  6007084220226030000
# 2                S                        -1  6004226420226030000
# 3                S                        -1  6004798220226030000
# 4                N                        -1  6002407820226030000
#
#    CD_SITUACAO_CANDIDATO_PLEITO DS_SITUACAO_CANDIDATO_PLEITO
# 0                             2                     DEFERIDO  \
# 1                             2                     DEFERIDO
# 2                             2                     DEFERIDO
# 3                             2                     DEFERIDO
# 4                             2                     DEFERIDO
#
#    CD_SITUACAO_CANDIDATO_URNA DS_SITUACAO_CANDIDATO_URNA
# 0                           2                   DEFERIDO  \
# 1                           2                   DEFERIDO
# 2                           2                   DEFERIDO
# 3                           2                   DEFERIDO
# 4                           2                   DEFERIDO
#
#   ST_CANDIDATO_INSERIDO_URNA NM_TIPO_DESTINACAO_VOTOS
# 0                        SIM                   Válido  \
# 1                        SIM                   Válido
# 2                        SIM                   Válido
# 3                        SIM                   Válido
# 4                        SIM                   Válido
#
#    CD_SITUACAO_CANDIDATO_TOT DS_SITUACAO_CANDIDATO_TOT ST_PREST_CONTAS
# 0                          2                  Deferido               S
# 1                          2                  Deferido               S
# 2                          2                  Deferido               S
# 3                          2                  Deferido               S
# 4                          2                  Deferido               S

# %%
# informação sobre o tamanho do dataframe (qnt. linhas, qnt. colunas)
candidaturas_pe.shape
# Out:
# (557, 71)

# %% [markdown]
# ## Quantas candidaturas houveram no seu município nas eleições de 2022?

# %% [markdown]
# ## Aula 7: Carregando tabelas
#
# É possível ler vários arquivos CSV e converter de uma só vez para dataframe Pandas. Para isso, além de usar as técnicas vistas nas aulas anteriores, importaremos a biblioteca glob.

# %%
import glob

# %%
dados_todos_estados = glob.glob('base_dados/consulta_*.csv')
print(dados_todos_estados)
# Out:
# ['base_dados/consulta_cand_2022_PA.csv', 'base_dados/consulta_cand_2022_AP.csv']

# %% [markdown]
# Vamos ler todos os arquivos e reunir em uma lista.

# %%
lista_df = []

for dados_estado in dados_todos_estados:
    df_estado = pd.read_csv(dados_estado, sep=';', encoding='latin_1')
    lista_df.append(df_estado)

# %% [markdown]
# Com o método `pd.concat` poderemos reunir os dataframes de cada estado em um único

# %%
df_completo = pd.concat(lista_df, axis=0, ignore_index=True)
df_completo.shape
# Out:
# (1600, 71)
